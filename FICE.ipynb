# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import train_test_split

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Path to the zip file in your Google Drive
zip_path ='/content/drive/MyDrive/PolypDB (1).zip'

# Unzipping the dataset
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/polyp_dataset')

# Check if the dataset is unzipped successfully
extracted_path = '/content/polyp_dataset/'
print(os.listdir(extracted_path))
# Out:
# ['PolypDB', '__MACOSX']

# %%
import os
import numpy as np
from skimage.io import imread, imshow, imsave
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import albumentations as A
import random

# Define dataset paths
image_dir = '/content/polyp_dataset/PolypDB/PolypDB_modality_wise/FICE/images'
mask_dir = '/content/polyp_dataset/PolypDB/PolypDB_modality_wise/FICE/masks'

# Image parameters
IMG_HEIGHT, IMG_WIDTH = 256, 256
CHANNELS = 3
TARGET_SIZE = 800  # Augmented dataset size

# Get sorted file lists
image_files = sorted([f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
mask_files = sorted([f for f in os.listdir(mask_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])

# Check image-mask consistency
if len(image_files) != len(mask_files):
    print(f"Warning: Image-mask count mismatch. Images: {len(image_files)}, Masks: {len(mask_files)}")
else:
    print(f"Found {len(image_files)} image-mask pairs.")

def load_and_preprocess(index):
    """Load, resize, and preprocess an image-mask pair."""
    image_path = os.path.join(image_dir, image_files[index])
    mask_path = os.path.join(mask_dir, mask_files[index])

    image = imread(image_path)
    mask = imread(mask_path, as_gray=True)

    # Ensure correct shape (for RGBA images)
    if image.shape[-1] == 4:
        image = image[:, :, :3]

    image = resize(image, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)
    mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)

    # Convert mask to binary
    mask = (mask > 0.5).astype(np.uint8)

    return (image * 255).astype(np.uint8), mask

# Augmentation Pipelines (Reduced p values for better variation)
aug = A.Compose([
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.Transpose(p=0.5),
    A.GridDistortion(p=0.3),  # Lowered probability
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5)  # Added color augmentation
])

# Augmented dataset directories
img_augmented_path = "/content/fice_augmented_image"
msk_augmented_path = "/content/fice_augmented_mask"

# Create directories if they don't exist
os.makedirs(img_augmented_path, exist_ok=True)
os.makedirs(msk_augmented_path, exist_ok=True)

# Load and preprocess images
all_x = []
all_y = []

for count in range(len(image_files)):
    x, y = load_and_preprocess(count)
    all_x.append(x)
    all_y.append(y)

# Convert lists to numpy arrays
all_x = np.array(all_x)
all_y = np.expand_dims(np.array(all_y), axis=-1)  # Add an extra dimension for the mask

# Split dataset (80% train, 10% val, 10% test)
x_train, x_temp, y_train, y_temp = train_test_split(all_x, all_y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# Print dataset shapes
print(f"Training set: {x_train.shape}, {y_train.shape}")
print(f"Validation set: {x_val.shape}, {y_val.shape}")
print(f"Test set: {x_test.shape}, {y_test.shape}")

# Augment the training data (up to TARGET_SIZE)
aug_x_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.uint8)
aug_y_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)

for count in range(TARGET_SIZE):
    index = random.randint(0, len(x_train) - 1)
    image = x_train[index]
    mask = y_train[index, :, :, 0]

    # Augment the image and mask
    augmented = aug(image=image, mask=mask)
    aug_x_train[count] = augmented['image']
    aug_y_train[count, :, :, 0] = augmented['mask']

    # Optionally save augmented images and masks
    new_image_path = os.path.join(img_augmented_path, f"augmented_image_{count}.png")
    new_mask_path = os.path.join(msk_augmented_path, f"augmented_mask_{count}.png")

    imsave(new_image_path, aug_x_train[count])
    imsave(new_mask_path, aug_y_train[count, :, :, 0])
# Combine original and augmented data
final_x_train = np.concatenate((x_train, aug_x_train), axis=0)
final_y_train = np.concatenate((y_train, aug_y_train), axis=0)

# Print the new dataset size
print(f"Final Training set: {final_x_train.shape}, {final_y_train.shape}")

# Optionally shuffle the dataset
indices = np.arange(final_x_train.shape[0])
np.random.shuffle(indices)

final_x_train = final_x_train[indices]
final_y_train = final_y_train[indices]

# Display a sample image and mask
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
imshow(aug_x_train[0])
plt.title("Augmented Image")
plt.subplot(1, 2, 2)
imshow(aug_y_train[0, :, :, 0], cmap='gray')
plt.title("Augmented Mask")
plt.show()
# Out:
# Found 70 image-mask pairs.
# Training set: (56, 256, 256, 3), (56, 256, 256, 1)
# Validation set: (7, 256, 256, 3), (7, 256, 256, 1)
# Test set: (7, 256, 256, 3), (7, 256, 256, 1)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_0.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_1.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_2.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_3.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_4.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_5.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_6.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_7.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_8.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_9.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_10.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_11.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_12.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_13.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_14.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_15.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_16.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_17.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_18.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_19.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_20.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_21.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_22.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_23.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_24.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_25.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_26.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_27.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_28.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_29.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_30.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_31.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_32.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_33.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_34.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_35.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_36.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_37.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_38.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_39.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_40.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_41.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_42.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_43.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_44.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_45.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_46.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_47.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_48.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_49.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_50.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_51.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_52.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_53.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_54.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_55.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_56.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_57.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_58.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_59.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_60.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_61.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_62.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_63.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_64.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_65.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_66.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_67.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_68.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_69.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_70.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_71.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_72.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_73.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_74.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_75.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_76.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_77.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_78.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_79.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_80.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_81.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_82.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_83.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_84.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_85.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_86.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_87.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_88.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_89.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_90.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_91.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_92.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_93.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_94.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_95.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_96.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_97.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_98.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_99.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_100.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_101.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_102.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_103.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_104.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_105.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_106.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_107.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_108.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_109.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_110.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_111.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_112.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_113.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_114.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_115.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_116.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_117.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_118.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_119.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_120.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_121.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_122.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_123.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_124.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_125.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_126.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_127.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_128.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_129.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_130.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_131.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_132.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_133.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_134.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_135.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_136.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_137.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_138.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_139.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_140.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_141.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_142.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_143.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_144.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_145.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_146.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_147.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_148.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_149.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_150.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_151.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_152.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_153.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_154.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_155.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_156.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_157.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_158.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_159.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_160.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_161.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_162.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_163.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_164.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_165.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_166.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_167.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_168.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_169.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_170.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_171.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_172.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_173.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_174.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_175.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_176.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_177.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_178.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_179.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_180.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_181.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_182.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_183.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_184.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_185.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_186.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_187.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_188.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_189.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_190.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_191.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_192.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_193.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_194.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_195.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_196.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_197.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_198.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_199.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_200.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_201.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_202.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_203.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_204.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_205.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_206.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_207.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_208.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_209.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_210.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_211.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_212.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_213.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_214.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_215.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_216.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_217.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_218.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_219.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_220.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_221.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_222.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_223.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_224.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_225.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_226.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_227.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_228.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_229.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_230.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_231.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_232.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_233.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_234.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_235.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_236.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_237.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_238.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_239.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_240.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_241.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_242.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_243.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_244.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_245.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_246.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_247.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_248.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_249.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_250.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_251.png is a low contrast image
#   return func(*args, **kwargs)
# ...
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_720.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_721.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_722.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_723.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_724.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_725.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_726.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_727.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_728.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_729.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_730.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_731.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_732.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_733.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_734.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_735.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_736.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_737.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_738.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_739.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_740.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_741.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_742.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_743.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_744.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_745.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_746.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_747.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_748.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_749.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_750.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_751.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_752.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_753.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_754.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_755.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_756.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_757.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_758.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_759.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_760.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_761.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_762.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_763.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_764.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_765.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_766.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_767.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_768.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_769.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_770.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_771.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_772.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_773.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_774.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_775.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_776.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_777.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_778.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_779.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_780.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_781.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_782.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_783.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_784.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_785.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_786.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_787.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_788.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_789.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_790.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_791.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_792.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_793.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_794.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_795.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_796.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_797.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_798.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/skimage/_shared/utils.py:328: UserWarning: /content/fice_augmented_mask/augmented_mask_799.png is a low contrast image
#   return func(*args, **kwargs)
# Final Training set: (856, 256, 256, 3), (856, 256, 256, 1)
# <ipython-input-4-4fe4abba0202>:126: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(aug_x_train[0])
# <ipython-input-4-4fe4abba0202>:129: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(aug_y_train[0, :, :, 0], cmap='gray')
# /usr/local/lib/python3.11/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
np.save("/content/final-x-train.npy", final_x_train)
np.save("/content/final-y-train.npy", final_y_train)

# %%
import numpy as np

# Load the saved arrays
final_x_train = np.load("/content/final-x-train.npy")
final_y_train = np.load("/content/final-y-train.npy")

# Print the shapes
print("final_x_train shape:", final_x_train.shape)
print("final_y_train shape:", final_y_train.shape)
# Out:
# final_x_train shape: (856, 256, 256, 3)
# final_y_train shape: (856, 256, 256, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

IMG_SIZE = 256  # Ensure the output matches this size

def se_block(input_tensor, ratio=16):
    """ Squeeze-and-Excitation Block """
    channels = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(channels // ratio, activation="relu")(se)
    se = Dense(channels, activation="sigmoid")(se)
    se = Reshape((1, 1, channels))(se)
    return Multiply()([input_tensor, se])

def drop_block(x, drop_prob=0.2, block_size=3):
    """ DropBlock Implementation """
    if drop_prob == 0.0:
        return x
    return Dropout(rate=drop_prob)(x)

def unet_efficientnetb4(input_size=(IMG_SIZE, IMG_SIZE, 3)):
    base_model = tf.keras.applications.EfficientNetB4(
        include_top=False,
        weights="imagenet",
        input_shape=input_size
    )

    # Encoder Feature Maps
    s1 = base_model.get_layer("block2a_expand_activation").output  # (64x64, 32)
    s2 = base_model.get_layer("block3a_expand_activation").output  # (32x32, 56)
    s3 = base_model.get_layer("block4a_expand_activation").output  # (16x16, 112)
    s4 = base_model.get_layer("block6a_expand_activation").output  # (8x8, 272)
    b5 = base_model.get_layer("top_activation").output  # (4x4, 1792) Bottleneck

    # Decoder with SE blocks, DropBlock, Dilated Convolutions, and L2 Regularization
    u6 = UpSampling2D(size=(2, 2))(b5)
    u6 = Conv2D(272, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u6)
    u6 = concatenate([u6, s4])
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u6)
    c6 = drop_block(c6)
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c6)
    c6 = se_block(c6)

    u7 = UpSampling2D(size=(2, 2))(c6)
    u7 = Conv2D(112, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u7)
    u7 = concatenate([u7, s3])
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u7)
    c7 = drop_block(c7)
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c7)
    c7 = se_block(c7)

    u8 = UpSampling2D(size=(2, 2))(c7)
    u8 = Conv2D(56, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u8)
    u8 = concatenate([u8, s2])
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u8)
    c8 = drop_block(c8)
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c8)
    c8 = se_block(c8)

    u9 = UpSampling2D(size=(2, 2))(c8)
    u9 = Conv2D(32, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u9)
    u9 = concatenate([u9, s1])
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u9)
    c9 = drop_block(c9)
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c9)
    c9 = se_block(c9)

    u10 = UpSampling2D(size=(2, 2))(c9)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u10)
    c10 = drop_block(c10)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c10)

    # 🚀 Final layer should output (256, 256, 1)
    outputs = Conv2D(1, (1, 1), activation="sigmoid")(c10)  # (256, 256, 1)

    return Model(inputs=base_model.input, outputs=outputs)

model = unet_efficientnetb4()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 
_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 64, 64, 32)     │          4,608 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 64, 64, 32)     │            128 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 64, 64, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 64, 64, 192)    │          1,728 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 64, 64, 192)    │            768 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 64, 64, 192)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 192)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 64, 64, 192)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 64, 64, 32)     │          6,144 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 64, 64, 32)     │            128 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 64, 64, 32)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 64, 64, 32)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 64, 64, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_dwconv            │ (None, 64, 64, 192)    │          1,728 │ block2c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_bn                │ (None, 64, 64, 192)    │            768 │ block2c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_activation        │ (None, 64, 64, 192)    │              0 │ block2c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_squeeze        │ (None, 192)            │              0 │ block2c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_excite         │ (None, 64, 64, 192)    │              0 │ block2c_activation[0]… │
# │ (Multiply)                │                        │                │ block2c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 64, 64, 32)     │          6,144 │ block2c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 64, 64, 32)     │            128 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 64, 64, 32)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 64, 64, 32)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_activation │ (None, 64, 64, 192)    │              0 │ block2d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_dwconv            │ (None, 64, 64, 192)    │          1,728 │ block2d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_bn                │ (None, 64, 64, 192)    │            768 │ block2d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_activation        │ (None, 64, 64, 192)    │              0 │ block2d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_squeeze        │ (None, 192)            │              0 │ block2d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_excite         │ (None, 64, 64, 192)    │              0 │ block2d_activation[0]… │
# │ (Multiply)                │                        │                │ block2d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_conv      │ (None, 64, 64, 32)     │          6,144 │ block2d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_bn        │ (None, 64, 64, 32)     │            128 │ block2d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_drop (Dropout)    │ (None, 64, 64, 32)     │              0 │ block2d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_add (Add)         │ (None, 64, 64, 32)     │              0 │ block2d_drop[0][0],    │
# │                           │                        │                │ block2c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 64, 64, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand
0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 256, 256, 1)    │             33 │ conv2d_13[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,690,893 (86.56 MB)
#  Trainable params: 22,565,686 (86.08 MB)
#  Non-trainable params: 125,207 (489.09 KB)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def tversky_loss(y_true, y_pred, alpha=0.6, beta=0.4, epsilon=1e-6):
    # Flatten the input tensors
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    # True Positives (TP), False Positives (FP), False Negatives (FN)
    TP = tf.reduce_sum(y_true * y_pred)
    FP = tf.reduce_sum((1 - y_true) * y_pred)
    FN = tf.reduce_sum(y_true * (1 - y_pred))

    # Calculate the Tversky Index
    tversky_index = (TP + epsilon) / (TP + alpha * FP + beta * FN + epsilon)

    # Tversky Loss is the complement of the Tversky Index
    return 1 - tversky_index




# Loss and Metric Functions
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = intersection / (union + 1e-6)
    return 1 - iou

def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    y_true = tf.cast(y_true, tf.float32)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    loss = alpha * tf.pow(1 - y_pred, gamma) * bce
    return loss

# %%
def combo_loss(y_true, y_pred, dice_weight=0.3, bce_weight=0.2,iou_weight=0.2,tversky_weight=0.3, pos_weight=6.0, neg_weight=1.0):
    y_true = tf.cast(y_true, tf.float32)

    # Dice Loss
    dice = dice_loss(y_true, y_pred)

    # Binary Cross-Entropy (Weighted)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    weighted_bce = pos_weight * y_true * bce + neg_weight * (1 - y_true) * bce

    # IoU Loss
    iou = iou_loss(y_true, y_pred)

    # Tversky Loss (For Imbalance)
    tversky = tversky_loss(y_true, y_pred)

    # Compute final loss with weights
    return (dice_weight * dice +
            bce_weight * tf.reduce_mean(weighted_bce) + iou_weight * iou + tversky_weight * tversky
            )

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import Adam


# Define Adam optimizer with an initial learning rate
initial_lr = 1e-4
optimizer = Adam(learning_rate=initial_lr)


def lr_schedule(epoch, lr):
    if epoch < 5:  # Warmup phase
        return lr * 1.5  # Increase LR to stabilize training
    elif epoch < 30:
        return lr * 0.98  # Gradual decay
    else:
        return lr * 0.95  # Final stabilization

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
import tensorflow.keras.backend as K

smooth = 1


def iou(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return intersection / (union + 1e-6)
# Create the metric objects outside the functions
prec = tf.keras.metrics.Precision()
rec = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 2 * ((p * r) / (p + r + 1e-6))

def f2_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 5 * ((p * r) / ((4 * p) + r + 1e-6))

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))  # Cast y_true to float32
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# In your model.compile call:
model.compile(optimizer=optimizer, loss=combo_loss, metrics=[iou,dice_coef, f1_score, f2_score, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,            # Stop if no improvement for 5 epochs
    restore_best_weights=True  # Restore best model weights
)

# Compile the model (assuming bce_dice_loss, iou, f1_score, etc., are defined)
# model.compile(optimizer=Adam(learning_rate=1e-4), loss=bce_dice_loss, metrics=[iou, f1_score, f2_score, Precision(), Recall()])

# Train the model with Early Stopping
history = model.fit(
    final_x_train, final_y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=8,
    callbacks=[early_stopping,lr_scheduler]  # Add the Early Stopping callback
)
# Out:
# Epoch 1/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 236s 484ms/step - dice_coef: 0.2730 - f1_score: 0.2202 - f2_score: 0.2203 - iou: 0.1919 - loss: 0.8379 - precision_1: 0.4565 - recall_1: 0.2263 - val_dice_coef: 0.8763 - val_f1_score: 0.8811 - val_f2_score: 0.8408 - val_iou: 0.7798 - val_loss: 0.2836 - val_precision_1: 0.9575 - val_recall_1: 0.8159 - learning_rate: 1.5000e-04
# Epoch 2/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 78s 218ms/step - dice_coef: 0.8607 - f1_score: 0.8677 - f2_score: 0.8610 - iou: 0.7604 - loss: 0.2930 - precision_1: 0.8952 - recall_1: 0.8602 - val_dice_coef: 0.9422 - val_f1_score: 0.9443 - val_f2_score: 0.9238 - val_iou: 0.8907 - val_loss: 0.2002 - val_precision_1: 0.9805 - val_recall_1: 0.9107 - learning_rate: 2.2500e-04
# Epoch 3/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - dice_coef: 0.9142 - f1_score: 0.9177 - f2_score: 0.9106 - iou: 0.8435 - loss: 0.2253 - precision_1: 0.9375 - recall_1: 0.9082 - val_dice_coef: 0.9580 - val_f1_score: 0.9605 - val_f2_score: 0.9713 - val_iou: 0.9193 - val_loss: 0.1727 - val_precision_1: 0.9431 - val_recall_1: 0.9786 - learning_rate: 3.3750e-04
# Epoch 4/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - dice_coef: 0.9366 - f1_score: 0.9393 - f2_score: 0.9364 - iou: 0.8823 - loss: 0.1886 - precision_1: 0.9480 - recall_1: 0.9357 - val_dice_coef: 0.9552 - val_f1_score: 0.9570 - val_f2_score: 0.9624 - val_iou: 0.9143 - val_loss: 0.1625 - val_precision_1: 0.9483 - val_recall_1: 0.9660 - learning_rate: 5.0625e-04
# Epoch 5/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - dice_coef: 0.9329 - f1_score: 0.9356 - f2_score: 0.9286 - iou: 0.8751 - loss: 0.1818 - precision_1: 0.9542 - recall_1: 0.9220 - val_dice_coef: 0.9401 - val_f1_score: 0.9423 - val_f2_score: 0.9292 - val_iou: 0.8870 - val_loss: 0.1659 - val_precision_1: 0.9648 - val_recall_1: 0.9207 - learning_rate: 7.5938e-04
# Epoch 6/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s
50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - dice_coef: 0.9834 - f1_score: 0.9841 - f2_score: 0.9823 - iou: 0.9674 - loss: 0.0280 - precision_1: 0.9882 - recall_1: 0.9829 - val_dice_coef: 0.9661 - val_f1_score: 0.9662 - val_f2_score: 0.9540 - val_iou: 0.9344 - val_loss: 0.0532 - val_precision_1: 0.9873 - val_recall_1: 0.9460 - learning_rate: 1.7292e-04
# Epoch 50/50
# 107/107 ━━━━━━━━━━━━━━━━━━━━ 23s 219ms/step - dice_coef: 0.9835 - f1_score: 0.9842 - f2_score: 0.9826 - iou: 0.9676 - loss: 0.0277 - precision_1: 0.9875 - recall_1: 0.9824 - val_dice_coef: 0.9682 - val_f1_score: 0.9686 - val_f2_score: 0.9578 - val_iou: 0.9384 - val_loss: 0.0503 - val_precision_1: 0.9871 - val_recall_1: 0.9507 - learning_rate: 1.6428e-04

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()
def plot_loss(history):
    plt.figure(figsize=(8, 6))

    # Plot training & validation loss
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Val Loss', color='red')

    # Labels and title
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# Call the function after training
plot_loss(history)

# %%
y_pred = model.predict(x_test)  # Predict masks for test images
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step

# %%
y_pred_thresholded = (y_pred > 0.5).astype(np.uint8)  # Convert probability map to binary mask

# %%
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
print("y_pred shape:", y_pred.shape)
print("y_pred_thresholded shape:", y_pred_thresholded.shape)
# Out:
# x_test shape: (7, 256, 256, 3)
# y_test shape: (7, 256, 256, 1)
# y_pred shape: (7, 256, 256, 1)
# y_pred_thresholded shape: (7, 256, 256, 1)

# %%
import matplotlib.pyplot as plt
import random

# Select a random test image
index = random.randint(0, len(x_test) - 1)

plt.figure(figsize=(15, 5))

# Original test image
plt.subplot(1, 3, 1)
plt.imshow(x_test[index])
plt.title("Test Image")

# Ground truth mask
plt.subplot(1, 3, 2)
plt.imshow(y_test[index, :, :, 0], cmap='gray')
plt.title("Ground Truth Mask")

# Predicted mask (thresholded)
plt.subplot(1, 3, 3)
plt.imshow(y_pred_thresholded[index, :, :, 0], cmap='gray')
plt.title("Predicted Mask")

plt.show()

# %%
# Lists to store scores
dice_scores = []
iou_scores = []

# Loop through each test sample
for i in range(len(y_test)):
    # Convert to float32 before calculation
    y_true = y_test[i].astype(np.float32)
    y_pred = y_pred_thresholded[i].astype(np.float32)

    # Calculate Dice and IoU for each sample
    dice = dice_coef(y_true, y_pred)
    iou_score = iou(y_true, y_pred)  # Assuming `iou` is your IoU function

    # Append scores
    dice_scores.append(dice)
    iou_scores.append(iou_score)

# Calculate mean scores
mean_dice = np.mean(dice_scores)
mean_iou = np.mean(iou_scores)

# Print results
print(f"Mean Dice Score: {mean_dice:.4f}")
print(f"Mean IoU Score: {mean_iou:.4f}")
# Out:
# Mean Dice Score: 0.9475
# Mean IoU Score: 0.9030

# %%
import tensorflow as tf
import numpy as np

# Lists to store scores
dice_scores = []
iou_scores = []

# Initialize the Keras Precision and Recall metrics
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Loop through each test sample
for i in range(len(y_test)):
    # Convert to float32 before calculation
    y_true = y_test[i].astype(np.float32)
    y_pred = y_pred_thresholded[i].astype(np.float32)

    # Calculate Dice, IoU, Precision, and Recall for each sample
    dice = dice_coef(y_true, y_pred)
    iou_score = iou(y_true, y_pred)  # Assuming iou is your IoU function

    # Update the Precision and Recall metrics
    precision_metric.update_state(y_true, y_pred)
    recall_metric.update_state(y_true, y_pred)

    # Append scores
    dice_scores.append(dice)
    iou_scores.append(iou_score)

# Final Precision and Recall after iterating through all test samples
mean_precision = precision_metric.result().numpy()
mean_recall = recall_metric.result().numpy()

# Calculate mean scores
mean_dice = np.mean(dice_scores)
mean_iou = np.mean(iou_scores)

# Compute F1 and F2 scores
if mean_precision + mean_recall > 0:
    f1_score = 2 * (mean_precision * mean_recall) / (mean_precision + mean_recall)
    f2_score = 5 * (mean_precision * mean_recall) / (4 * mean_precision + mean_recall)
else:
    f1_score, f2_score = 0.0, 0.0  # Avoid division by zero

# Print results
print(f"Mean Dice Score: {mean_dice:.4f}")
print(f"Mean IoU Score: {mean_iou:.4f}")
print(f"Mean Precision: {mean_precision:.4f}")
print(f"Mean Recall: {mean_recall:.4f}")


print(f"F1 Score: {f1_score:.4f}")
print(f"F2 Score: {f2_score:.4f}")
# Out:
# Mean Dice Score: 0.9475
# Mean IoU Score: 0.9030
# Mean Precision: 0.9782
# Mean Recall: 0.9403
# F1 Score: 0.9589
# F2 Score: 0.9477

# %%
import tensorflow as tf

# Lists to store scores
dice_scores = []
iou_scores = []
precision_scores = []
recall_scores = []

# Initialize the Keras Precision and Recall metrics
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Loop through each test sample
for i in range(len(y_test)):
    # Convert to float32 before calculation
    y_true = y_test[i].astype(np.float32)
    y_pred = y_pred_thresholded[i].astype(np.float32)

    # Calculate Dice, IoU, Precision, and Recall for each sample
    dice = dice_coef(y_true, y_pred)
    iou_score = iou(y_true, y_pred)  # Assuming `iou` is your IoU function

    # Update the Precision and Recall metrics
    precision_metric.update_state(y_true, y_pred)
    recall_metric.update_state(y_true, y_pred)

    # Append scores
    dice_scores.append(dice)
    iou_scores.append(iou_score)

# Final Precision and Recall after iterating through all test samples
mean_precision = precision_metric.result().numpy()
mean_recall = recall_metric.result().numpy()

# Calculate mean scores
mean_dice = np.mean(dice_scores)
mean_iou = np.mean(iou_scores)

# Print results
print(f"Mean Dice Score: {mean_dice:.4f}")
print(f"Mean IoU Score: {mean_iou:.4f}")
print(f"Mean Precision: {mean_precision:.4f}")
print(f"Mean Recall: {mean_recall:.4f}")
# Out:
# Mean Dice Score: 0.9475
# Mean IoU Score: 0.9030
# Mean Precision: 0.9782
# Mean Recall: 0.9403

# %%
model.save('/content/drive/My Drive/FICEeff.h5')  # Saves model to Drive
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save('/content/drive/My Drive/FICEeff.keras')  # Saves model to Drive
