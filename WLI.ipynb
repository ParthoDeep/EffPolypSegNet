# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import train_test_split

# %%
import os

dataset_path = '/kaggle/input/polyp-dataset'
print(os.listdir(dataset_path))
# Out:
# ['PolypDB']

# %%
pip install albumentations
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: albumentations in /opt/conda/lib/python3.10/site-packages (1.4.17)
# Requirement already satisfied: numpy>=1.24.4 in /opt/conda/lib/python3.10/site-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from albumentations) (1.14.1)
# Requirement already satisfied: scikit-image>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from albumentations) (0.23.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.7.0 in /opt/conda/lib/python3.10/site-packages (from albumentations) (2.9.2)
# Requirement already satisfied: albucore==0.0.17 in /opt/conda/lib/python3.10/site-packages (from albumentations) (0.0.17)
# Requirement already satisfied: eval-type-backport in /opt/conda/lib/python3.10/site-packages (from albumentations) (0.2.0)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /opt/conda/lib/python3.10/site-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.7.0->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.7.0->albumentations) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic>=2.7.0->albumentations) (4.12.2)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.21.0->albumentations) (3.3)
# Requirement already satisfied: pillow>=9.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.21.0->albumentations) (10.3.0)
# Requirement already satisfied: imageio>=2.33 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.21.0->albumentations) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.21.0->albumentations) (2024.5.22)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.21.0->albumentations) (21.3)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/conda/lib/python3.10/site-packages (from scikit-image>=0.21.0->albumentations) (0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image>=0.21.0->albumentations) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from skimage.io import imread, imshow, imsave
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import albumentations as A
import random

# Define dataset paths
image_dir = '/kaggle/input/polyp-dataset/PolypDB/PolypDB_modality_wise/WLI/images'
mask_dir = '/kaggle/input/polyp-dataset/PolypDB/PolypDB_modality_wise/WLI/masks'

# Image parameters
IMG_HEIGHT, IMG_WIDTH = 256, 256
CHANNELS = 3
TARGET_SIZE = 20000  # Augmented dataset size

# Get sorted file lists
image_files = sorted([f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
mask_files = sorted([f for f in os.listdir(mask_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])

# Check image-mask consistency
if len(image_files) != len(mask_files):
    print(f"Warning: Image-mask count mismatch. Images: {len(image_files)}, Masks: {len(mask_files)}")
else:
    print(f"Found {len(image_files)} image-mask pairs.")

def load_and_preprocess(index):
    """Load, resize, and preprocess an image-mask pair."""
    image_path = os.path.join(image_dir, image_files[index])
    mask_path = os.path.join(mask_dir, mask_files[index])

    image = imread(image_path)
    mask = imread(mask_path, as_gray=True)

    # Ensure correct shape (for RGBA images)
    if image.shape[-1] == 4:
        image = image[:, :, :3]

    image = resize(image, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)
    mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)

    # Convert mask to binary
    mask = (mask > 0.5).astype(np.uint8)

    return (image * 255).astype(np.uint8), mask

# Augmentation Pipelines (Reduced p values for better variation)
aug = A.Compose([
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.Transpose(p=0.5),
    A.GridDistortion(p=0.3),  # Lowered probability
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5)  # Added color augmentation
])

# Augmented dataset directories
img_augmented_path = "/kaggle/working/augmented_image"
msk_augmented_path = "/kaggle/working/augmented_mask"

# Create directories if they don't exist
os.makedirs(img_augmented_path, exist_ok=True)
os.makedirs(msk_augmented_path, exist_ok=True)

# Load and preprocess images
all_x = []
all_y = []

for count in range(len(image_files)):
    x, y = load_and_preprocess(count)
    all_x.append(x)
    all_y.append(y)

# Convert lists to numpy arrays
all_x = np.array(all_x)
all_y = np.expand_dims(np.array(all_y), axis=-1)  # Add an extra dimension for the mask

# Split dataset (80% train, 10% val, 10% test)
x_train, x_temp, y_train, y_temp = train_test_split(all_x, all_y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# Print dataset shapes
print(f"Training set: {x_train.shape}, {y_train.shape}")
print(f"Validation set: {x_val.shape}, {y_val.shape}")
print(f"Test set: {x_test.shape}, {y_test.shape}")

# Augment the training data (up to TARGET_SIZE)
aug_x_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.uint8)
aug_y_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)

for count in range(TARGET_SIZE):
    index = random.randint(0, len(x_train) - 1)
    image = x_train[index]
    mask = y_train[index, :, :, 0]

    # Augment the image and mask
    augmented = aug(image=image, mask=mask)
    aug_x_train[count] = augmented['image']
    aug_y_train[count, :, :, 0] = augmented['mask']

    # Optionally save augmented images and masks
    new_image_path = os.path.join(img_augmented_path, f"augmented_image_{count}.png")
    new_mask_path = os.path.join(msk_augmented_path, f"augmented_mask_{count}.png")

    imsave(new_image_path, aug_x_train[count])
    imsave(new_mask_path, aug_y_train[count, :, :, 0])
# Combine original and augmented data
final_x_train = np.concatenate((x_train, aug_x_train), axis=0)
final_y_train = np.concatenate((y_train, aug_y_train), axis=0)

# Print the new dataset size
print(f"Final Training set: {final_x_train.shape}, {final_y_train.shape}")

# Optionally shuffle the dataset
indices = np.arange(final_x_train.shape[0])
np.random.shuffle(indices)

final_x_train = final_x_train[indices]
final_y_train = final_y_train[indices]

# Display a sample image and mask
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
imshow(aug_x_train[0])
plt.title("Augmented Image")
plt.subplot(1, 2, 2)
imshow(aug_y_train[0, :, :, 0], cmap='gray')
plt.title("Augmented Mask")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 2.0.5 (you have 1.4.17). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# Found 3588 image-mask pairs.
# Training set: (2870, 256, 256, 3), (2870, 256, 256, 1)
# Validation set: (359, 256, 256, 3), (359, 256, 256, 1)
# Test set: (359, 256, 256, 3), (359, 256, 256, 1)
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_0.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_1.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_2.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_3.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_4.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_5.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_6.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_7.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_8.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_9.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_11.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_12.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_13.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_14.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_15.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_16.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_17.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_18.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_19.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_20.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_21.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_22.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_23.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_24.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_25.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_26.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_27.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_28.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_29.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_30.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_31.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_32.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_33.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_34.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_35.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_36.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_37.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_38.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_39.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_40.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_41.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_42.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_43.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_44.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_45.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_46.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_47.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_48.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_49.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_50.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_51.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_52.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_53.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_54.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_55.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_56.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_57.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_58.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_59.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_60.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_61.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_62.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_63.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_64.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_65.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_66.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_67.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_68.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_69.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_70.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_71.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_72.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_73.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_74.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_75.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_76.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_77.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_78.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_79.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_80.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_81.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_82.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_83.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_84.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_85.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_86.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_87.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_88.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_89.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_90.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_91.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_92.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_93.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_94.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_95.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_96.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_97.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_98.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_99.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_100.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_101.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_102.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_103.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_104.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_105.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_106.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_107.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_108.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_109.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_110.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_111.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_112.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_113.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_114.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_115.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_116.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_117.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_118.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_119.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_120.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_121.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_122.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_123.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_124.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_125.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_126.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_127.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_128.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_129.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_130.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_131.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_132.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_133.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_134.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_135.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_136.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_137.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_138.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_139.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_140.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_141.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_142.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_143.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_144.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_145.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_146.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_147.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_148.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_149.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_150.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_151.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_152.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_153.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_154.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_155.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_156.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_157.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_158.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_159.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_160.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_161.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_162.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_163.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_164.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_165.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_166.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_167.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_168.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_169.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_170.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_171.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_172.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_173.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_174.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_175.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_176.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_177.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_178.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_179.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_180.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_181.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_182.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_183.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_184.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_185.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_186.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_187.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_188.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_189.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_190.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_191.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_192.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_193.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_194.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_195.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_196.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_197.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_198.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_199.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_200.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_201.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_202.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_203.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_204.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_205.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_206.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_207.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_208.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_209.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_210.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_211.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_212.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_213.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_214.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_215.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_216.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_217.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_218.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_219.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_220.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_221.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_222.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_223.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_224.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_225.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_226.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_227.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_228.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_229.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_230.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_231.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_232.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_233.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_234.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_235.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_236.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_237.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_238.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_239.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_240.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_241.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_242.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_243.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_244.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_245.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_246.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_247.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_248.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_249.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_250.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_251.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_252.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_253.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_254.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_255.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_256.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_257.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_258.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_259.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_260.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_261.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_262.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# ...
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10107.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10108.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10109.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10110.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10111.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10112.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10113.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10114.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10115.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10116.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10117.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10118.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10119.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10120.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10121.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10122.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10123.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10124.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10125.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10126.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10127.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10128.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10129.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10130.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10131.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10132.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10133.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10134.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10135.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10136.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10137.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10138.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10139.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10140.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10141.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10142.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10143.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10144.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10145.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10146.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10147.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10148.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10149.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10150.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10151.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10152.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10153.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10154.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10155.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10156.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10157.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10158.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10159.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10160.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10161.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10162.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10163.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10164.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10165.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10166.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10167.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10168.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10169.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10170.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10171.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10172.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10173.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10174.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10175.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10176.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10177.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10178.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10179.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10180.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10181.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10182.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10183.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10184.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10185.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10186.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10187.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10188.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10189.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10190.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10191.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10192.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])
# /tmp/ipykernel_30/2763744834.py:108: UserWarning: /kaggle/working/augmented_mask/augmented_mask_10193.png is a low contrast image
#   imsave(new_mask_path, aug_y_train[count, :, :, 0])

# %%
np.save("/kaggle/working/final-x-train.npy", final_x_train)
np.save("/kaggle/working/final-y-train.npy", final_y_train)

# %%
import numpy as np

# Load the saved arrays
final_x_train = np.load("/kaggle/working/final-x-train.npy")
final_y_train = np.load("/kaggle/working/final-y-train.npy")

# Print the shapes
print("final_x_train shape:", final_x_train.shape)
print("final_y_train shape:", final_y_train.shape)
# Out:
# final_x_train shape: (22870, 256, 256, 3)
# final_y_train shape: (22870, 256, 256, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

IMG_SIZE = 256  # Ensure the output matches this size

def se_block(input_tensor, ratio=16):
    """ Squeeze-and-Excitation Block """
    channels = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(channels // ratio, activation="relu")(se)
    se = Dense(channels, activation="sigmoid")(se)
    se = Reshape((1, 1, channels))(se)
    return Multiply()([input_tensor, se])

def drop_block(x, drop_prob=0.2, block_size=3):
    """ DropBlock Implementation """
    if drop_prob == 0.0:
        return x
    return Dropout(rate=drop_prob)(x)

def unet_efficientnetb4(input_size=(IMG_SIZE, IMG_SIZE, 3)):
    base_model = tf.keras.applications.EfficientNetB4(
        include_top=False,
        weights="imagenet",
        input_shape=input_size
    )

    # Encoder Feature Maps
    s1 = base_model.get_layer("block2a_expand_activation").output  # (64x64, 32)
    s2 = base_model.get_layer("block3a_expand_activation").output  # (32x32, 56)
    s3 = base_model.get_layer("block4a_expand_activation").output  # (16x16, 112)
    s4 = base_model.get_layer("block6a_expand_activation").output  # (8x8, 272)
    b5 = base_model.get_layer("top_activation").output  # (4x4, 1792) Bottleneck

    # Decoder with SE blocks, DropBlock, Dilated Convolutions, and L2 Regularization
    u6 = UpSampling2D(size=(2, 2))(b5)
    u6 = Conv2D(272, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u6)
    u6 = concatenate([u6, s4])
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u6)
    c6 = drop_block(c6)
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c6)
    c6 = se_block(c6)

    u7 = UpSampling2D(size=(2, 2))(c6)
    u7 = Conv2D(112, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u7)
    u7 = concatenate([u7, s3])
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u7)
    c7 = drop_block(c7)
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c7)
    c7 = se_block(c7)

    u8 = UpSampling2D(size=(2, 2))(c7)
    u8 = Conv2D(56, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u8)
    u8 = concatenate([u8, s2])
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u8)
    c8 = drop_block(c8)
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c8)
    c8 = se_block(c8)

    u9 = UpSampling2D(size=(2, 2))(c8)
    u9 = Conv2D(32, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u9)
    u9 = concatenate([u9, s1])
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u9)
    c9 = drop_block(c9)
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c9)
    c9 = se_block(c9)

    u10 = UpSampling2D(size=(2, 2))(c9)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u10)
    c10 = drop_block(c10)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c10)

    # 🚀 Final layer should output (256, 256, 1)
    outputs = Conv2D(1, (1, 1), activation="sigmoid")(c10)  # (256, 256, 1)

    return Model(inputs=base_model.input, outputs=outputs)

model = unet_efficientnetb4()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization       │ (None, 256, 256,  │          7 │ rescaling[0][0]   │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 256, 256,  │          0 │ normalization[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 257, 257,  │          0 │ rescaling_1[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 128, 128,  │      1,296 │ stem_conv_pad[0]… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 128, 128,  │        192 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 128, 128,  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 128, 128,  │        432 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 128, 128,  │        192 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 128, 128,  │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 48)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 48)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 12)  │        588 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 48)  │        624 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 128, 128,  │          0 │ block1a_activati… │
# │ (Multiply)          │ 48)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 128, 128,  │      1,152 │ block1a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 128, 128,  │         96 │ block1a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_dwconv      │ (None, 128, 128,  │        216 │ block1a_project_… │
# │ (DepthwiseConv2D)   │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_bn          │ (None, 128, 128,  │         96 │ block1b_dwconv[0… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_activation  │ (None, 128, 128,  │          0 │ block1b_bn[0][0]  │
# │ (Activation)        │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_squeeze  │ (None, 24)        │          0 │ block1b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_reshape  │ (None, 1, 1, 24)  │          0 │ block1b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_reduce   │ (None, 1, 1, 6)   │        150 │ block1b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_expand   │ (None, 1, 1, 24)  │        168 │ block1b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_se_excite   │ (None, 128, 128,  │          0 │ block1b_activati… │
# │ (Multiply)          │ 24)               │            │ block1b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_co… │ (None, 128, 128,  │        576 │ block1b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_project_bn  │ (None, 128, 128,  │         96 │ block1b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_drop        │ (None, 128, 128,  │          0 │ block1b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1b_add (Add)   │ (None, 128, 128,  │          0 │ block1b_drop[0][… │
# │                     │ 24)               │            │ block1a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 128, 128,  │      3,456 │ block1b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 128, 128,  │        576 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 128, 128,  │          0 │ block2a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 129, 129,  │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 64, 64,    │      1,296 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 64, 64,    │        576 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 64, 64,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 144)       │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 144) │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 64, 64,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 144)              │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 64, 64,    │      4,608 │ block2a_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 64, 64,    │        128 │ block2a_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 64, 64,    │      6,144 │ block2a_project_… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 64, 64,    │        768 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 64, 64,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 64, 64,    │      1,728 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 64, 64,    │        768 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 64, 64,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 192)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 192) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 64, 64,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 192)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 64, 64,    │      6,144 │ block2b_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 64, 64,    │        128 │ block2b_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 64, 64,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 64, 64,    │          0 │ block2b_drop[0][… │
# │                     │ 32)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_conv │ (None, 64, 64,    │      6,144 │ block2b_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_bn   │ (None, 64, 64,    │        768 │ block2c_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_expand_act… │ (None, 64, 64,    │          0 │ block2c_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_dwconv      │ (None, 64, 64,    │      1,728 │ block2c_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_bn          │ (None, 64, 64,    │        768 │ block2c_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_activation  │ (None, 64, 64,    │          0 │ block2c_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_squeeze  │ (None, 192)       │          0 │ block2c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_reshape  │ (None, 1, 1, 192) │          0 │ block2c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_se_excite   │ (None, 64, 64,    │          0 │ block2c_activati… │
# │ (Multiply)          │ 192)              │            │ block2c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_co… │ (None, 64, 64,    │      6,144 │ block2c_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_project_bn  │ (None, 64, 64,    │        128 │ block2c_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_drop        │ (None, 64, 64,    │          0 │ block2c_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2c_add (Add)   │ (None, 64, 64,    │          0 │ block2c_drop[0][… │
# │                     │ 32)               │            │ block2b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_conv │ (None, 64, 64,    │      6,144 │ block2c_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_bn   │ (None, 64, 64,    │        768 │ block2d_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_expand_act… │ (None, 64, 64,    │          0 │ block2d_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_dwconv      │ (None, 64, 64,    │      1,728 │ block2d_expand_a… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_bn          │ (None, 64, 64,    │        768 │ block2d_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_activation  │ (None, 64, 64,    │          0 │ block2d_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_squeeze  │ (None, 192)       │          0 │ block2d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_reshape  │ (None, 1, 1, 192) │          0 │ block2d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block2d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_expand   │ (None, 1, 1, 192) │      1,728 │ block2d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_se_excite   │ (None, 64, 64,    │          0 │ block2d_activati… │
# │ (Multiply)          │ 192)              │            │ block2d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_co… │ (None, 64, 64,    │      6,144 │ block2d_se_excit… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_project_bn  │ (None, 64, 64,    │        128 │ block2d_project_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_drop        │ (None, 64, 64,    │          0 │ block2d_project_… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2d_add (Add)   │ (None, 64, 64,    │          0 │ block2d_drop[0][… │
# │                     │ 32)               │            │ block2c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 64, 64,    │      6,144 │ block2d_add[0][0] │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 64, 64,    │        768 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 64, 64,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 67, 67,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 32, 32,    │      4,800 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 32, 32,    │        768 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 32, 32,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 192)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 192) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 8)   │      1,544 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 192) │      1,728 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 32, 32,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 192)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 32, 32,    │     10,752 │ block3a_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 32, 32,    │        224 │ block3a_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 32, 32,    │     18,816 │ block3a_project_… │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 32, 32,    │      1,344 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 32, 32,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 32, 32,    │      8,400 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 32, 32,    │      1,344 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 32, 32,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 336)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 336) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 336) │      5,040 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 32, 32,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 336)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 32, 32,    │     18,816 │ block3b_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 32, 32,    │        224 │ block3b_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 32, 32,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 32, 32,    │          0 │ block3b_drop[0][… │
# │                     │ 56)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_conv │ (None, 32, 32,    │     18,816 │ block3b_add[0][0] │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_bn   │ (None, 32, 32,    │      1,344 │ block3c_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_expand_act… │ (None, 32, 32,    │          0 │ block3c_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_dwconv      │ (None, 32, 32,    │      8,400 │ block3c_expand_a… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_bn          │ (None, 32, 32,    │      1,344 │ block3c_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_activation  │ (None, 32, 32,    │          0 │ block3c_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_squeeze  │ (None, 336)       │          0 │ block3c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_reshape  │ (None, 1, 1, 336) │          0 │ block3c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block3c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_expand   │ (None, 1, 1, 336) │      5,040 │ block3c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_se_excite   │ (None, 32, 32,    │          0 │ block3c_activati… │
# │ (Multiply)          │ 336)              │            │ block3c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_co… │ (None, 32, 32,    │     18,816 │ block3c_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_project_bn  │ (None, 32, 32,    │        224 │ block3c_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_drop        │ (None, 32, 32,    │          0 │ block3c_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3c_add (Add)   │ (None, 32, 32,    │          0 │ block3c_drop[0][… │
# │                     │ 56)               │            │ block3b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_conv │ (None, 32, 32,    │     18,816 │ block3c_add[0][0] │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_bn   │ (None, 32, 32,    │      1,344 │ block3d_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_expand_act… │ (None, 32, 32,    │          0 │ block3d_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_dwconv      │ (None, 32, 32,    │      8,400 │ block3d_expand_a… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_bn          │ (None, 32, 32,    │      1,344 │ block3d_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_activation  │ (None, 32, 32,    │          0 │ block3d_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_squeeze  │ (None, 336)       │          0 │ block3d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_reshape  │ (None, 1, 1, 336) │          0 │ block3d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block3d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_expand   │ (None, 1, 1, 336) │      5,040 │ block3d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_se_excite   │ (None, 32, 32,    │          0 │ block3d_activati… │
# │ (Multiply)          │ 336)              │            │ block3d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_project_co… │ (None, 32, 32,    │     18,816 │ block3d_se_excit… │
# │ (Conv2D)            │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_project_bn  │ (None, 32, 32,    │        224 │ block3d_project_… │
# │ (BatchNormalizatio… │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_drop        │ (None, 32, 32,    │          0 │ block3d_project_… │
# │ (Dropout)           │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3d_add (Add)   │ (None, 32, 32,    │          0 │ block3d_drop[0][… │
# │                     │ 56)               │            │ block3c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 32, 32,    │     18,816 │ block3d_add[0][0] │
# │ (Conv2D)            │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 32, 32,    │      1,344 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 32, 32,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 33, 33,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 16, 16,    │      3,024 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 16, 16,    │      1,344 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 16, 16,    │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │ 336)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 336)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 336) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 14)  │      4,718 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 336) │      5,040 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 16, 16,    │          0 │ block4a_activati… │
# │ (Multiply)          │ 336)              │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 16, 16,    │     37,632 │ block4a_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 16, 16,    │        448 │ block4a_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 16, 16,    │     75,264 │ block4a_project_… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 16, 16,    │      2,688 │ block4b_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 16, 16,    │          0 │ block4b_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 16, 16,    │      6,048 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 16, 16,    │      2,688 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 16, 16,    │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 672)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 672) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 16, 16,    │          0 │ block4b_activati… │
# │ (Multiply)          │ 672)              │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 16, 16,    │     75,264 │ block4b_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 16, 16,    │        448 │ block4b_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 16, 16,    │          0 │ block4b_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 16, 16,    │          0 │ block4b_drop[0][… │
# │                     │ 112)              │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 16, 16,    │     75,264 │ block4b_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 16, 16,    │      2,688 │ block4c_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 16, 16,    │          0 │ block4c_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 16, 16,    │      6,048 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 16, 16,    │      2,688 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 16, 16,    │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 672)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 672) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 16, 16,    │          0 │ block4c_activati… │
# │ (Multiply)          │ 672)              │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 16, 16,    │     75,264 │ block4c_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 16, 16,    │        448 │ block4c_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 16, 16,    │          0 │ block4c_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 16, 16,    │          0 │ block4c_drop[0][… │
# │                     │ 112)              │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_conv │ (None, 16, 16,    │     75,264 │ block4c_add[0][0] │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_bn   │ (None, 16, 16,    │      2,688 │ block4d_expand_c… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_expand_act… │ (None, 16, 16,    │          0 │ block4d_expand_b… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_dwconv      │ (None, 16, 16,    │      6,048 │ block4d_expand_a… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_bn          │ (None, 16, 16,    │      2,688 │ block4d_dwconv[0… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_activation  │ (None, 16, 16,    │          0 │ block4d_bn[0][0]  │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_squeeze  │ (None, 672)       │          0 │ block4d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_reshape  │ (None, 1, 1, 672) │          0 │ block4d_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block4d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_expand   │ (None, 1, 1, 672) │     19,488 │ block4d_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_se_excite   │ (None, 16, 16,    │          0 │ block4d_activati… │
# │ (Multiply)          │ 672)              │            │ block4d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_project_co… │ (None, 16, 16,    │     75,264 │ block4d_se_excit… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_project_bn  │ (None, 16, 16,    │        448 │ block4d_project_… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4d_drop        │ (None, 16, 16,    │          0 │ block4d_project_… │
# │ (Dropout)           │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# │ (Reshape)           │ 1632)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 68)  │    111,044 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │    112,608 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1632)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 8, 8,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1632)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 8, 8, 448) │    731,136 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 8, 8, 448) │      1,792 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_conv │ (None, 8, 8,      │  1,204,224 │ block7a_project_… │
# │ (Conv2D)            │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_bn   │ (None, 8, 8,      │     10,752 │ block7b_expand_c… │
# │ (BatchNormalizatio… │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_expand_act… │ (None, 8, 8,      │          0 │ block7b_expand_b… │
# │ (Activation)        │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_dwconv      │ (None, 8, 8,      │     24,192 │ block7b_expand_a… │
# │ (DepthwiseConv2D)   │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_bn          │ (None, 8, 8,      │     10,752 │ block7b_dwconv[0… │
# │ (BatchNormalizatio… │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_activation  │ (None, 8, 8,      │          0 │ block7b_bn[0][0]  │
# │ (Activation)        │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_squeeze  │ (None, 2688)      │          0 │ block7b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_reshape  │ (None, 1, 1,      │          0 │ block7b_se_squee… │
# │ (Reshape)           │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_reduce   │ (None, 1, 1, 112) │    301,168 │ block7b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_expand   │ (None, 1, 1,      │    303,744 │ block7b_se_reduc… │
# │ (Conv2D)            │ 2688)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_se_excite   │ (None, 8, 8,      │          0 │ block7b_activati… │
# │ (Multiply)          │ 2688)             │            │ block7b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_project_co… │ (None, 8, 8, 448) │  1,204,224 │ block7b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_project_bn  │ (None, 8, 8, 448) │      1,792 │ block7b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_drop        │ (None, 8, 8, 448) │          0 │ block7b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7b_add (Add)   │ (None, 8, 8, 448) │          0 │ block7b_drop[0][… │
# │                     │                   │            │ block7a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 8, 8,      │    802,816 │ block7b_add[0][0] │
# │                     │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 8, 8,      │      7,168 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 8, 8,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 16, 16,    │          0 │ top_activation[0… │
# │ (UpSampling2D)      │ 1792)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │    487,696 │ up_sampling2d[0]… │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d[0][0],     │
# │ (Concatenate)       │ 1232)             │            │ block6a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │  3,016,208 │ concatenate[0][0] │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 16, 16,    │          0 │ conv2d_1[0][0]    │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │    666,128 │ dropout[0][0]     │
# │                     │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 272)       │          0 │ conv2d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 17)        │      4,641 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 272)       │      4,896 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 272) │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16, 16,    │          0 │ conv2d_2[0][0],   │
# │                     │ 272)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 32, 32,    │          0 │ multiply[0][0]    │
# │ (UpSampling2D)      │ 272)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │     30,576 │ up_sampling2d_1[… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ conv2d_3[0][0],   │
# │ (Concatenate)       │ 448)              │            │ block4a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │    451,696 │ concatenate_1[0]… │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32, 32,    │          0 │ conv2d_4[0][0]    │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    113,008 │ dropout_1[0][0]   │
# │                     │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 112)       │          0 │ conv2d_5[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 7)         │        791 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 112)       │        896 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 112) │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ conv2d_5[0][0],   │
# │ (Multiply)          │ 112)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 64, 64,    │          0 │ multiply_1[0][0]  │
# │ (UpSampling2D)      │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      6,328 │ up_sampling2d_2[… │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64, 64,    │          0 │ conv2d_6[0][0],   │
# │ (Concatenate)       │ 248)              │            │ block3a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │    125,048 │ concatenate_2[0]… │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64, 64,    │          0 │ conv2d_7[0][0]    │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │     28,280 │ dropout_2[0][0]   │
# │                     │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 56)        │          0 │ conv2d_8[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 3)         │        171 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 56)        │        224 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 56)  │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 64, 64,    │          0 │ conv2d_8[0][0],   │
# │ (Multiply)          │ 56)               │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 128, 128,  │          0 │ multiply_2[0][0]  │
# │ (UpSampling2D)      │ 56)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 128,  │      1,824 │ up_sampling2d_3[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 128, 128,  │          0 │ conv2d_9[0][0],   │
# │ (Concatenate)       │ 176)              │            │ block2a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │     50,720 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128, 128,  │          0 │ conv2d_10[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │      9,248 │ dropout_3[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ conv2d_11[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 2)         │         66 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 32)        │         96 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 32)  │          0 │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 128, 128,  │          0 │ conv2d_11[0][0],  │
# │ (Multiply)          │ 32)               │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_4     │ (None, 256, 256,  │          0 │ multiply_3[0][0]  │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │      9,248 │ up_sampling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 256, 256,  │          0 │ conv2d_12[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │      9,248 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │         33 │ conv2d_13[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 22,690,893 (86.56 MB)
#  Trainable params: 22,565,686 (86.08 MB)
#  Non-trainable params: 125,207 (489.09 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define Adam optimizer with an initial learning rate
initial_lr = 1e-4
optimizer = Adam(learning_rate=initial_lr)

# Define ReduceLROnPlateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # Monitor validation loss
    factor=0.5,          # Reduce LR by half
    patience=5,          # Wait 5 epochs before reducing LR
    verbose=1,           # Print message when LR is reduced
    min_lr=1e-6          # Minimum LR limit
)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def tversky_loss(y_true, y_pred, alpha=0.6, beta=0.4, epsilon=1e-6):
    # Flatten the input tensors
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    # True Positives (TP), False Positives (FP), False Negatives (FN)
    TP = tf.reduce_sum(y_true * y_pred)
    FP = tf.reduce_sum((1 - y_true) * y_pred)
    FN = tf.reduce_sum(y_true * (1 - y_pred))

    # Calculate the Tversky Index
    tversky_index = (TP + epsilon) / (TP + alpha * FP + beta * FN + epsilon)

    # Tversky Loss is the complement of the Tversky Index
    return 1 - tversky_index




# Loss and Metric Functions
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = intersection / (union + 1e-6)
    return 1 - iou

def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    y_true = tf.cast(y_true, tf.float32)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    loss = alpha * tf.pow(1 - y_pred, gamma) * bce
    return loss

# %%
def combo_loss(y_true, y_pred, dice_weight=0.3, bce_weight=0.2,iou_weight=0.2,tversky_weight=0.3, pos_weight=6.0, neg_weight=1.0):
    y_true = tf.cast(y_true, tf.float32)

    # Dice Loss
    dice = dice_loss(y_true, y_pred)

    # Binary Cross-Entropy (Weighted)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    weighted_bce = pos_weight * y_true * bce + neg_weight * (1 - y_true) * bce

    # IoU Loss
    iou = iou_loss(y_true, y_pred)

    # Tversky Loss (For Imbalance)
    tversky = tversky_loss(y_true, y_pred)

    # Compute final loss with weights
    return (dice_weight * dice +
            bce_weight * tf.reduce_mean(weighted_bce) + iou_weight * iou + tversky_weight * tversky
            )

# %%
import tensorflow.keras.backend as K

smooth = 1


def iou(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return intersection / (union + 1e-6)
# Create the metric objects outside the functions
prec = tf.keras.metrics.Precision()
rec = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 2 * ((p * r) / (p + r + 1e-6))

def f2_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 5 * ((p * r) / ((4 * p) + r + 1e-6))

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))  # Cast y_true to float32
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# In your model.compile call:
model.compile(optimizer=optimizer, loss=combo_loss, metrics=[iou,dice_coef, f1_score, f2_score, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,            # Stop if no improvement for 5 epochs
    restore_best_weights=True  # Restore best model weights
)

# Compile the model (assuming bce_dice_loss, iou, f1_score, etc., are defined)
# model.compile(optimizer=Adam(learning_rate=1e-4), loss=bce_dice_loss, metrics=[iou, f1_score, f2_score, Precision(), Recall()])

# Train the model with Early Stopping
history = model.fit(
    final_x_train, final_y_train,
    validation_data=(x_val, y_val),
    epochs=25,
    batch_size=8,
    callbacks=[early_stopping,reduce_lr]  # Add the Early Stopping callback
)
# Out:
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1743229698.693379     107 service.cc:145] XLA service 0x79a02c004520 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1743229698.694212     107 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1743229855.081714     107 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 851s 220ms/step - dice_coef: 0.7607 - f1_score: 0.7626 - f2_score: 0.7610 - iou: 0.6500 - loss: 0.3930 - precision_1: 0.8173 - recall_1: 0.7488 - val_dice_coef: 0.8848 - val_f1_score: 0.8896 - val_f2_score: 0.8756 - val_iou: 0.8004 - val_loss: 0.2195 - val_precision_1: 0.9152 - val_recall_1: 0.8700 - learning_rate: 1.0000e-04
# Epoch 2/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 457s 160ms/step - dice_coef: 0.9205 - f1_score: 0.9246 - f2_score: 0.9201 - iou: 0.8551 - loss: 0.1688 - precision_1: 0.9391 - recall_1: 0.9143 - val_dice_coef: 0.8886 - val_f1_score: 0.8932 - val_f2_score: 0.8874 - val_iou: 0.8060 - val_loss: 0.1772 - val_precision_1: 0.9044 - val_recall_1: 0.8867 - learning_rate: 1.0000e-04
# Epoch 3/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 457s 160ms/step - dice_coef: 0.9343 - f1_score: 0.9375 - f2_score: 0.9348 - iou: 0.8785 - loss: 0.1221 - precision_1: 0.9484 - recall_1: 0.9329 - val_dice_coef: 0.9037 - val_f1_score: 0.9060 - val_f2_score: 0.8964 - val_iou: 0.8316 - val_loss: 0.1485 - val_precision_1: 0.9283 - val_recall_1: 0.8804 - learning_rate: 1.0000e-04
# Epoch 4/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 457s 160ms/step - dice_coef: 0.9415 - f1_score: 0.9445 - f2_score: 0.9418 - iou: 0.8910 - loss: 0.0983 - precision_1: 0.9541 - recall_1: 0.9405 - val_dice_coef: 0.8912 - val_f1_score: 0.8942 - val_f2_score: 0.8673 - val_iou: 0.8114 - val_loss: 0.1512 - val_precision_1: 0.9482 - val_recall_1: 0.8483 - learning_rate: 1.0000e-04
# Epoch 5/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 456s 160ms/step - dice_coef: 0.9463 - f1_score: 0.9489 - f2_score: 0.9465 - iou: 0.8993 - loss: 0.0845 - precision_1: 0.9579 - recall_1: 0.9453 - val_dice_coef: 0.8876 - val_f1_score: 0.8907 - val_f2_score: 0.8700 - val_iou: 0.8065 - val_loss: 0.1486 - val_precision_1: 0.9372 - val_recall_1: 0.8542 - learning_rate: 1.0000e-04
# Epoch 6/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 456s 159ms/step - dice_coef: 0.9496 - f1_score: 0.9521 - f2_score: 0.9494 - iou: 0.9053 - loss: 0.0758 - precision_1: 0.9606 - recall_1: 0.9494 - val_dice_coef: 0.8952 - val_f1_score: 0.8974 - val_f2_score: 0.8937 - val_iou: 0.8174 - val_loss: 0.1440 - val_precision_1: 0.9080 - val_recall_1: 0.8865 - learning_rate: 1.0000e-04
# Epoch 7/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 455s 159ms/step - dice_coef: 0.9500 - f1_score: 0.9524 - f2_score: 0.9503 - iou: 0.9058 - loss: 0.0729 - precision_1: 0.9598 - recall_1: 0.9501 - val_dice_coef: 0.9055 - val_f1_score: 0.9068 - val_f2_score: 0.8988 - val_iou: 0.8340 - val_loss: 0.1306 - val_precision_1: 0.9259 - val_recall_1: 0.8885 - learning_rate: 1.0000e-04
# Epoch 8/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 454s 159ms/step - dice_coef: 0.9551 - f1_score: 0.9572 - f2_score: 0.9550 - iou: 0.9147 - loss: 0.0647 - precision_1: 0.9643 - recall_1: 0.9549 - val_dice_coef: 0.8977 - val_f1_score: 0.8993 - val_f2_score: 0.8920 - val_iou: 0.8215 - val_loss: 0.1358 - val_precision_1: 0.9167 - val_recall_1: 0.8845 - learning_rate: 1.0000e-04
# Epoch 9/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 453s 158ms/step - dice_coef: 0.9581 - f1_score: 0.9601 - f2_score: 0.9584 - iou: 0.9201 - loss: 0.0601 - precision_1: 0.9659 - recall_1: 0.9590 - val_dice_coef: 0.8950 - val_f1_score: 0.8972 - val_f2_score: 0.8852 - val_iou: 0.8173 - val_loss: 0.1379 - val_precision_1: 0.9226 - val_recall_1: 0.8683 - learning_rate: 1.0000e-04
# Epoch 10/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9573 - f1_score: 0.9594 - f2_score: 0.9571 - iou: 0.9189 - loss: 0.0601 - precision_1: 0.9663 - recall_1: 0.9569 - val_dice_coef: 0.9071 - val_f1_score: 0.9089 - val_f2_score: 0.9056 - val_iou: 0.8364 - val_loss: 0.1246 - val_precision_1: 0.9141 - val_recall_1: 0.9048 - learning_rate: 1.0000e-04
# Epoch 11/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 453s 158ms/step - dice_coef: 0.9604 - f1_score: 0.9623 - f2_score: 0.9602 - iou: 0.9243 - loss: 0.0554 - precision_1: 0.9684 - recall_1: 0.9608 - val_dice_coef: 0.8934 - val_f1_score: 0.8956 - val_f2_score: 0.8841 - val_iou: 0.8174 - val_loss: 0.1364 - val_precision_1: 0.9267 - val_recall_1: 0.8756 - learning_rate: 1.0000e-04
# Epoch 12/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 453s 158ms/step - dice_coef: 0.9612 - f1_score: 0.9631 - f2_score: 0.9611 - iou: 0.9258 - loss: 0.0535 - precision_1: 0.9691 - recall_1: 0.9617 - val_dice_coef: 0.9040 - val_f1_score: 0.9052 - val_f2_score: 0.9046 - val_iou: 0.8319 - val_loss: 0.1335 - val_precision_1: 0.9085 - val_recall_1: 0.8986 - learning_rate: 1.0000e-04
# Epoch 13/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9604 - f1_score: 0.9623 - f2_score: 0.9599 - iou: 0.9245 - loss: 0.0542 - precision_1: 0.9692 - recall_1: 0.9600 - val_dice_coef: 0.9110 - val_f1_score: 0.9127 - val_f2_score: 0.9172 - val_iou: 0.8429 - val_loss: 0.1167 - val_precision_1: 0.9105 - val_recall_1: 0.9212 - learning_rate: 1.0000e-04
# Epoch 14/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 451s 158ms/step - dice_coef: 0.9640 - f1_score: 0.9657 - f2_score: 0.9638 - iou: 0.9308 - loss: 0.0492 - precision_1: 0.9713 - recall_1: 0.9644 - val_dice_coef: 0.8999 - val_f1_score: 0.9015 - val_f2_score: 0.9133 - val_iou: 0.8248 - val_loss: 0.1401 - val_precision_1: 0.8851 - val_recall_1: 0.9165 - learning_rate: 1.0000e-04
# Epoch 15/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9638 - f1_score: 0.9655 - f2_score: 0.9636 - iou: 0.9305 - loss: 0.0490 - precision_1: 0.9711 - recall_1: 0.9644 - val_dice_coef: 0.9085 - val_f1_score: 0.9097 - val_f2_score: 0.9069 - val_iou: 0.8384 - val_loss: 0.1193 - val_precision_1: 0.9226 - val_recall_1: 0.9063 - learning_rate: 1.0000e-04
# Epoch 16/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 453s 158ms/step - dice_coef: 0.9660 - f1_score: 0.9676 - f2_score: 0.9656 - iou: 0.9345 - loss: 0.0459 - precision_1: 0.9730 - recall_1: 0.9664 - val_dice_coef: 0.8931 - val_f1_score: 0.8946 - val_f2_score: 0.8902 - val_iou: 0.8154 - val_loss: 0.1422 - val_precision_1: 0.9085 - val_recall_1: 0.8806 - learning_rate: 1.0000e-04
# Epoch 17/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9646 - f1_score: 0.9662 - f2_score: 0.9647 - iou: 0.9321 - loss: 0.0474 - precision_1: 0.9712 - recall_1: 0.9655 - val_dice_coef: 0.9115 - val_f1_score: 0.9131 - val_f2_score: 0.9100 - val_iou: 0.8424 - val_loss: 0.1182 - val_precision_1: 0.9207 - val_recall_1: 0.9018 - learning_rate: 1.0000e-04
# Epoch 18/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9666 - f1_score: 0.9682 - f2_score: 0.9666 - iou: 0.9357 - loss: 0.0445 - precision_1: 0.9732 - recall_1: 0.9678 - val_dice_coef: 0.9114 - val_f1_score: 0.9130 - val_f2_score: 0.9140 - val_iou: 0.8423 - val_loss: 0.1145 - val_precision_1: 0.9139 - val_recall_1: 0.9150 - learning_rate: 1.0000e-04
# Epoch 19/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 451s 158ms/step - dice_coef: 0.9652 - f1_score: 0.9669 - f2_score: 0.9652 - iou: 0.9336 - loss: 0.0463 - precision_1: 0.9721 - recall_1: 0.9660 - val_dice_coef: 0.9145 - val_f1_score: 0.9155 - val_f2_score: 0.9061 - val_iou: 0.8477 - val_loss: 0.1119 - val_precision_1: 0.9423 - val_recall_1: 0.8954 - learning_rate: 1.0000e-04
# Epoch 20/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 451s 158ms/step - dice_coef: 0.9679 - f1_score: 0.9694 - f2_score: 0.9676 - iou: 0.9381 - loss: 0.0426 - precision_1: 0.9746 - recall_1: 0.9688 - val_dice_coef: 0.9292 - val_f1_score: 0.9306 - val_f2_score: 0.9280 - val_iou: 0.8696 - val_loss: 0.0919 - val_precision_1: 0.9387 - val_recall_1: 0.9255 - learning_rate: 1.0000e-04
# Epoch 21/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 451s 158ms/step - dice_coef: 0.9678 - f1_score: 0.9693 - f2_score: 0.9679 - iou: 0.9379 - loss: 0.0429 - precision_1: 0.9736 - recall_1: 0.9691 - val_dice_coef: 0.9134 - val_f1_score: 0.9146 - val_f2_score: 0.9136 - val_iou: 0.8461 - val_loss: 0.1139 - val_precision_1: 0.9246 - val_recall_1: 0.9115 - learning_rate: 1.0000e-04
# Epoch 22/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 450s 158ms/step - dice_coef: 0.9694 - f1_score: 0.9708 - f2_score: 0.9692 - iou: 0.9408 - loss: 0.0406 - precision_1: 0.9755 - recall_1: 0.9701 - val_dice_coef: 0.9051 - val_f1_score: 0.9066 - val_f2_score: 0.8985 - val_iou: 0.8336 - val_loss: 0.1226 - val_precision_1: 0.9298 - val_recall_1: 0.8884 - learning_rate: 1.0000e-04
# Epoch 23/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9694 - f1_score: 0.9708 - f2_score: 0.9694 - iou: 0.9408 - loss: 0.0406 - precision_1: 0.9753 - recall_1: 0.9701 - val_dice_coef: 0.8944 - val_f1_score: 0.8959 - val_f2_score: 0.9005 - val_iou: 0.8208 - val_loss: 0.1412 - val_precision_1: 0.8874 - val_recall_1: 0.9006 - learning_rate: 1.0000e-04
# Epoch 24/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9701 - f1_score: 0.9715 - f2_score: 0.9700 - iou: 0.9421 - loss: 0.0396 - precision_1: 0.9760 - recall_1: 0.9710 - val_dice_coef: 0.9153 - val_f1_score: 0.9164 - val_f2_score: 0.9029 - val_iou: 0.8492 - val_loss: 0.1093 - val_precision_1: 0.9471 - val_recall_1: 0.8906 - learning_rate: 1.0000e-04
# Epoch 25/25
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - dice_coef: 0.9702 - f1_score: 0.9716 - f2_score: 0.9701 - iou: 0.9424 - loss: 0.0394 - precision_1: 0.9761 - recall_1: 0.9709
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 2859/2859 ━━━━━━━━━━━━━━━━━━━━ 452s 158ms/step - dice_coef: 0.9702 - f1_score: 0.9716 - f2_score: 0.9701 - iou: 0.9424 - loss: 0.0394 - precision_1: 0.9761 - recall_1: 0.9709 - val_dice_coef: 0.9062 - val_f1_score: 0.9076 - val_f2_score: 0.8979 - val_iou: 0.8355 - val_loss: 0.1226 - val_precision_1: 0.9321 - val_recall_1: 0.8862 - learning_rate: 1.0000e-04

# %%
print(final_x_train.shape, final_y_train.shape)  # Ensure both are (batch_size, 256, 256, 1)
print(x_val.shape, y_val.shape)
# Out:
# (22870, 256, 256, 3) (22870, 256, 256, 1)
# (359, 256, 256, 3) (359, 256, 256, 1)

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()
def plot_loss(history):
    plt.figure(figsize=(8, 6))

    # Plot training & validation loss
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Val Loss', color='red')

    # Labels and title
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# Call the function after training
plot_loss(history)

# %%
y_pred = model.predict(x_test)  # Predict masks for test images
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 26s 864ms/step

# %%
y_pred_thresholded = (y_pred > 0.5).astype(np.uint8)  # Convert probability map to binary mask

# %%
import matplotlib.pyplot as plt
import random

# Select a random test image
index = random.randint(0, len(x_test) - 1)

plt.figure(figsize=(15, 5))

# Original test image
plt.subplot(1, 3, 1)
plt.imshow(x_test[index])
plt.title("Test Image")

# Ground truth mask
plt.subplot(1, 3, 2)
plt.imshow(y_test[index, :, :, 0], cmap='gray')
plt.title("Ground Truth Mask")

# Predicted mask (thresholded)
plt.subplot(1, 3, 3)
plt.imshow(y_pred_thresholded[index, :, :, 0], cmap='gray')
plt.title("Predicted Mask")

plt.show()

# %%
import tensorflow as tf
import numpy as np

# Lists to store scores
dice_scores = []
iou_scores = []

# Initialize the Keras Precision and Recall metrics
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Loop through each test sample
for i in range(len(y_test)):
    # Convert to float32 before calculation
    y_true = y_test[i].astype(np.float32)
    y_pred = y_pred_thresholded[i].astype(np.float32)

    # Calculate Dice, IoU, Precision, and Recall for each sample
    dice = dice_coef(y_true, y_pred)
    iou_score = iou(y_true, y_pred)  # Assuming iou is your IoU function

    # Update the Precision and Recall metrics
    precision_metric.update_state(y_true, y_pred)
    recall_metric.update_state(y_true, y_pred)

    # Append scores
    dice_scores.append(dice)
    iou_scores.append(iou_score)

# Final Precision and Recall after iterating through all test samples
mean_precision = precision_metric.result().numpy()
mean_recall = recall_metric.result().numpy()

# Calculate mean scores
mean_dice = np.mean(dice_scores)
mean_iou = np.mean(iou_scores)

# Compute F1 and F2 scores
if mean_precision + mean_recall > 0:
    f1_score = 2 * (mean_precision * mean_recall) / (mean_precision + mean_recall)
    f2_score = 5 * (mean_precision * mean_recall) / (4 * mean_precision + mean_recall)
else:
    f1_score, f2_score = 0.0, 0.0  # Avoid division by zero

# Print results
print(f"Mean Dice Score: {mean_dice:.4f}")
print(f"Mean IoU Score: {mean_iou:.4f}")
print(f"Mean Precision: {mean_precision:.4f}")
print(f"Mean Recall: {mean_recall:.4f}")


print(f"F1 Score: {f1_score:.4f}")
print(f"F2 Score: {f2_score:.4f}")
# Out:
# Mean Dice Score: 0.9147
# Mean IoU Score: 0.8597
# Mean Precision: 0.9321
# Mean Recall: 0.9038
# F1 Score: 0.9177
# F2 Score: 0.9093
