# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Conv2D, Conv2DTranspose, MaxPooling2D, Dropout, Input, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall
from sklearn.model_selection import train_test_split

# %%
pip install -U albumentations
# Out:
# Requirement already satisfied: albumentations in /usr/local/lib/python3.10/dist-packages (2.0.5)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from albumentations) (6.0.2)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from albumentations) (2.11.0a2)
# Requirement already satisfied: albucore==0.0.23 in /usr/local/lib/python3.10/dist-packages (from albumentations) (0.0.23)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.10/dist-packages (from albumentations) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.23->albumentations) (3.11.1)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.10/dist-packages (from albucore==0.0.23->albumentations) (6.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24.4->albumentations) (2.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9.2->albumentations) (2.29.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.9.2->albumentations) (4.12.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24.4->albumentations) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24.4->albumentations) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.4->albumentations) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.24.4->albumentations) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.24.4->albumentations) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from skimage.io import imread, imshow, imsave
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import albumentations as A
import random

# Define dataset paths
image_dir = '/kaggle/input/cvc-polyp/CVC-ClinicDB/Original'
mask_dir = '/kaggle/input/cvc-polyp/CVC-ClinicDB/Ground Truth'

# Image parameters
IMG_HEIGHT, IMG_WIDTH = 256, 256
CHANNELS = 3
TARGET_SIZE = 1500  # Augmented dataset size4
# Get sorted file lists
image_files = sorted([f for f in os.listdir(image_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.tif'))])
mask_files = sorted([f for f in os.listdir(mask_dir) if f.lower().endswith(('.jpg', '.jpeg', '.png', '.tif'))])

# Check image-mask consistency
if len(image_files) != len(mask_files):
    print(f"Warning: Image-mask count mismatch. Images: {len(image_files)}, Masks: {len(mask_files)}")
else:
    print(f"Found {len(image_files)} image-mask pairs.")

def load_and_preprocess(index):
    """Load, resize, and preprocess an image-mask pair."""
    image_path = os.path.join(image_dir, image_files[index])
    mask_path = os.path.join(mask_dir, mask_files[index])

    image = imread(image_path)
    mask = imread(mask_path, as_gray=True)

    # Ensure correct shape (for RGBA images)
    if image.shape[-1] == 4:
        image = image[:, :, :3]

    image = resize(image, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)
    mask = resize(mask, (IMG_HEIGHT, IMG_WIDTH), mode='reflect', anti_aliasing=True)

    # Convert mask to binary
    mask = (mask > 0.5).astype(np.uint8)

    return (image * 255).astype(np.uint8), mask

# Augmentation Pipelines (Reduced p values for better variation)
aug = A.Compose([
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.Transpose(p=0.5),
    A.GridDistortion(p=0.3),  # Lowered probability
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1, p=0.5)  # Added color augmentation
])

# Augmented dataset directories
img_augmented_path = "/kaggle/working/augmented_images"
msk_augmented_path = "/kaggle/working/augmented_masks"

# Create directories if they don't exist
os.makedirs(img_augmented_path, exist_ok=True)
os.makedirs(msk_augmented_path, exist_ok=True)

# Load and preprocess images
all_x = []
all_y = []

for count in range(len(image_files)):
    x, y = load_and_preprocess(count)
    all_x.append(x)
    all_y.append(y)

# Convert lists to numpy arrays
all_x = np.array(all_x)
all_y = np.expand_dims(np.array(all_y), axis=-1)  # Add an extra dimension for the mask

# Split dataset (80% train, 10% val, 10% test)
x_train, x_temp, y_train, y_temp = train_test_split(all_x, all_y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# Print dataset shapes
print(f"Training set: {x_train.shape}, {y_train.shape}")
print(f"Validation set: {x_val.shape}, {y_val.shape}")
print(f"Test set: {x_test.shape}, {y_test.shape}")

# Augment the training data (up to TARGET_SIZE)
aug_x_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, CHANNELS), dtype=np.uint8)
aug_y_train = np.zeros((TARGET_SIZE, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.uint8)

for count in range(TARGET_SIZE):
    index = random.randint(0, len(x_train) - 1)
    image = x_train[index]
    mask = y_train[index, :, :, 0]

    # Augment the image and mask
    augmented = aug(image=image, mask=mask)
    aug_x_train[count] = augmented['image']
    aug_y_train[count, :, :, 0] = augmented['mask']

    # Optionally save augmented images and masks
    new_image_path = os.path.join(img_augmented_path, f"augmented_image_{count}.png")
    new_mask_path = os.path.join(msk_augmented_path, f"augmented_mask_{count}.png")

    imsave(new_image_path, aug_x_train[count])
    imsave(new_mask_path, aug_y_train[count, :, :, 0])
# Combine original and augmented data
final_x_train = np.concatenate((x_train, aug_x_train), axis=0)
final_y_train = np.concatenate((y_train, aug_y_train), axis=0)

# Print the new dataset size
print(f"Final Training set: {final_x_train.shape}, {final_y_train.shape}")

# Optionally shuffle the dataset
indices = np.arange(final_x_train.shape[0])
np.random.shuffle(indices)

final_x_train = final_x_train[indices]
final_y_train = final_y_train[indices]

# Display a sample image and mask
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
imshow(aug_x_train[0])
plt.title("Augmented Image")
plt.subplot(1, 2, 2)
imshow(aug_y_train[0, :, :, 0], cmap='gray')
plt.title("Augmented Mask")
plt.show()
# Out:
# Found 612 image-mask pairs.
# Training set: (489, 256, 256, 3), (489, 256, 256, 1)
# Validation set: (61, 256, 256, 3), (61, 256, 256, 1)
# Test set: (62, 256, 256, 3), (62, 256, 256, 1)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_0.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_2.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_3.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_4.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_5.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_6.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_7.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_8.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_9.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_10.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_11.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_12.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_13.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_14.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_15.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_16.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_17.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_18.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_19.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_20.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_21.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_22.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_23.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_24.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_25.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_26.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_27.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_28.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_29.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_30.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_31.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_32.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_33.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_34.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_35.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_36.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_37.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_38.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_39.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_40.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_41.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_42.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_43.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_44.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_45.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_46.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_47.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_48.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_49.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_50.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_51.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_52.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_53.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_54.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_55.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_56.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_57.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_58.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_59.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_60.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_61.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_62.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_63.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_64.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_65.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_66.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_67.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_68.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_69.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_70.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_71.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_72.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_73.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_74.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_75.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_76.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_77.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_78.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_79.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_80.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_81.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_82.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_83.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_84.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_85.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_86.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_87.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_88.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_89.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_90.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_91.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_92.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_93.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_94.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_95.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_96.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_97.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_98.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_99.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_100.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_101.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_102.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_103.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_104.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_105.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_106.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_107.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_108.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_109.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_110.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_111.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_112.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_113.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_114.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_115.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_116.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_117.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_118.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_119.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_120.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_121.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_122.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_123.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_124.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_125.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_126.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_127.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_128.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_129.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_130.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_131.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_132.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_133.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_134.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_135.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_136.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_137.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_138.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_139.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_140.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_141.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_142.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_143.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_144.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_145.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_146.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_147.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_148.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_149.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_150.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_151.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_152.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_153.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_154.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_155.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_156.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_157.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_158.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_159.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_160.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_161.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_162.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_163.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_164.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_165.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_166.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_167.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_168.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_169.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_170.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_171.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_172.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_173.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_174.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_175.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_176.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_177.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_178.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_179.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_180.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_181.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_182.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_183.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_184.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_185.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_186.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_187.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_188.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_189.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_190.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_191.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_192.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_193.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_194.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_195.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_196.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_197.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_198.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_199.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_200.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_201.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_202.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_203.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_204.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_205.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_206.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_207.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_208.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_209.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_210.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_211.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_212.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_213.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_214.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_215.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_216.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_217.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_218.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_219.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_220.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_221.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_222.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_223.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_224.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_225.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_226.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_227.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_228.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_229.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_230.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_231.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_232.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_233.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_234.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_235.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_236.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_237.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_238.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_239.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_240.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_241.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_242.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_243.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_244.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_245.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_246.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_247.png is a low contrast image
#   return func(*args, **kwargs)
# ...
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1422.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1423.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1424.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1425.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1426.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1427.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1428.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1429.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1430.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1431.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1432.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1433.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1434.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1435.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1436.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1437.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1438.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1439.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1440.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1441.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1442.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1443.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1444.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1445.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1446.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1447.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1448.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1449.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1450.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1451.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1452.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1453.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1454.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1455.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1456.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1457.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1458.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1459.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1460.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1461.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1462.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1463.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1464.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1465.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1466.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1467.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1468.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1469.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1470.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1471.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1472.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1473.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1474.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1475.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1476.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1477.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1478.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1479.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1480.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1481.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1482.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1483.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1484.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1485.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1486.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1487.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1488.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1489.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1490.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1491.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1492.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1493.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1494.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1495.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1496.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1497.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1498.png is a low contrast image
#   return func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/skimage/_shared/utils.py:328: UserWarning: /kaggle/working/augmented_masks/augmented_mask_1499.png is a low contrast image
#   return func(*args, **kwargs)
# Final Training set: (1989, 256, 256, 3), (1989, 256, 256, 1)
# <ipython-input-6-26e66b1aaa1d>:125: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(aug_x_train[0])
# <ipython-input-6-26e66b1aaa1d>:128: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(aug_y_train[0, :, :, 0], cmap='gray')
# /usr/local/lib/python3.10/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
np.save("/kaggle/working/final-x-train.npy", final_x_train)
np.save("/kaggle/working/final-y-train.npy", final_y_train)

# %%
import numpy as np

# Load the saved arrays
final_x_train = np.load("/kaggle/working/final-x-train.npy")
final_y_train = np.load("/kaggle/working/final-y-train.npy")

# Print the shapes
print("final_x_train shape:", final_x_train.shape)
print("final_y_train shape:", final_y_train.shape)
# Out:
# final_x_train shape: (1989, 256, 256, 3)
# final_y_train shape: (1989, 256, 256, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2

IMG_SIZE = 256  # Ensure the output matches this size

def se_block(input_tensor, ratio=16):
    """ Squeeze-and-Excitation Block """
    channels = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(channels // ratio, activation="relu")(se)
    se = Dense(channels, activation="sigmoid")(se)
    se = Reshape((1, 1, channels))(se)
    return Multiply()([input_tensor, se])

def drop_block(x, drop_prob=0.2, block_size=3):
    """ DropBlock Implementation """
    if drop_prob == 0.0:
        return x
    return Dropout(rate=drop_prob)(x)

def unet_efficientnetb4(input_size=(IMG_SIZE, IMG_SIZE, 3)):
    base_model = tf.keras.applications.EfficientNetB4(
        include_top=False,
        weights="imagenet",
        input_shape=input_size
    )

    # Encoder Feature Maps
    s1 = base_model.get_layer("block2a_expand_activation").output  # (64x64, 32)
    s2 = base_model.get_layer("block3a_expand_activation").output  # (32x32, 56)
    s3 = base_model.get_layer("block4a_expand_activation").output  # (16x16, 112)
    s4 = base_model.get_layer("block6a_expand_activation").output  # (8x8, 272)
    b5 = base_model.get_layer("top_activation").output  # (4x4, 1792) Bottleneck

    # Decoder with SE blocks, DropBlock, Dilated Convolutions, and L2 Regularization
    u6 = UpSampling2D(size=(2, 2))(b5)
    u6 = Conv2D(272, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u6)
    u6 = concatenate([u6, s4])
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u6)
    c6 = drop_block(c6)
    c6 = Conv2D(272, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c6)
    c6 = se_block(c6)

    u7 = UpSampling2D(size=(2, 2))(c6)
    u7 = Conv2D(112, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u7)
    u7 = concatenate([u7, s3])
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(u7)
    c7 = drop_block(c7)
    c7 = Conv2D(112, (3, 3), activation="relu", padding="same", dilation_rate=(2,2), kernel_regularizer=l2(1e-4))(c7)
    c7 = se_block(c7)

    u8 = UpSampling2D(size=(2, 2))(c7)
    u8 = Conv2D(56, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u8)
    u8 = concatenate([u8, s2])
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u8)
    c8 = drop_block(c8)
    c8 = Conv2D(56, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c8)
    c8 = se_block(c8)

    u9 = UpSampling2D(size=(2, 2))(c8)
    u9 = Conv2D(32, (1, 1), padding="same", kernel_regularizer=l2(1e-4))(u9)
    u9 = concatenate([u9, s1])
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u9)
    c9 = drop_block(c9)
    c9 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c9)
    c9 = se_block(c9)

    u10 = UpSampling2D(size=(2, 2))(c9)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(u10)
    c10 = drop_block(c10)
    c10 = Conv2D(32, (3, 3), activation="relu", padding="same", kernel_regularizer=l2(1e-4))(c10)

    # 🚀 Final layer should output (256, 256, 1)
    outputs = Conv2D(1, (1, 1), activation="sigmoid")(c10)  # (256, 256, 1)

    return Model(inputs=base_model.input, outputs=outputs)
model = unet_efficientnetb4()
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 256, 256, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ normalization             │ (None, 256, 256, 3)    │              7 │ rescaling[0][0]        │
# │ (Normalization)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling_1 (Rescaling)   │ (None, 256, 256, 3)    │              0 │ normalization[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv_pad             │ (None, 257, 257, 3)    │              0 │ rescaling_1[0][0]      │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 128, 128, 48)   │          1,296 │ stem_conv_pad[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 128, 128, 48)   │            192 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 128, 128, 48)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_dwconv            │ (None, 128, 128, 48)   │            432 │ stem_activation[0][0]  │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_bn                │ (None, 128, 128, 48)   │            192 │ block1a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_activation        │ (None, 128, 128, 48)   │              0 │ block1a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_squeeze        │ (None, 48)             │              0 │ block1a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reshape        │ (None, 1, 1, 48)       │              0 │ block1a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_reduce         │ (None, 1, 1, 12)       │            588 │ block1a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_expand         │ (None, 1, 1, 48)       │            624 │ block1a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_se_excite         │ (None, 128, 128, 48)   │              0 │ block1a_activation[0]… │
# │ (Multiply)                │                        │                │ block1a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 128, 128, 24)   │          1,152 │ block1a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 128, 128, 24)   │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_dwconv            │ (None, 128, 128, 24)   │            216 │ block1a_project_bn[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_bn                │ (None, 128, 128, 24)   │             96 │ block1b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_activation        │ (None, 128, 128, 24)   │              0 │ block1b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_squeeze        │ (None, 24)             │              0 │ block1b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reshape        │ (None, 1, 1, 24)       │              0 │ block1b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_reduce         │ (None, 1, 1, 6)        │            150 │ block1b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_expand         │ (None, 1, 1, 24)       │            168 │ block1b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_se_excite         │ (None, 128, 128, 24)   │              0 │ block1b_activation[0]… │
# │ (Multiply)                │                        │                │ block1b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 128, 128, 24)   │            576 │ block1b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 128, 128, 24)   │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 128, 128, 24)   │              0 │ block1b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 128, 128, 24)   │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 128, 128, 144)  │          3,456 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 128, 128, 144)  │            576 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 128, 128, 144)  │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv_pad        │ (None, 129, 129, 144)  │              0 │ block2a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_dwconv            │ (None, 64, 64, 144)    │          1,296 │ block2a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_bn                │ (None, 64, 64, 144)    │            576 │ block2a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_activation        │ (None, 64, 64, 144)    │              0 │ block2a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_squeeze        │ (None, 144)            │              0 │ block2a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reshape        │ (None, 1, 1, 144)      │              0 │ block2a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_reduce         │ (None, 1, 1, 6)        │            870 │ block2a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_expand         │ (None, 1, 1, 144)      │          1,008 │ block2a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_se_excite         │ (None, 64, 64, 144)    │              0 │ block2a_activation[0]… │
# │ (Multiply)                │                        │                │ block2a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 64, 64, 32)     │          4,608 │ block2a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 64, 64, 32)     │            128 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 64, 64, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_dwconv            │ (None, 64, 64, 192)    │          1,728 │ block2b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_bn                │ (None, 64, 64, 192)    │            768 │ block2b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_activation        │ (None, 64, 64, 192)    │              0 │ block2b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_squeeze        │ (None, 192)            │              0 │ block2b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_se_excite         │ (None, 64, 64, 192)    │              0 │ block2b_activation[0]… │
# │ (Multiply)                │                        │                │ block2b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 64, 64, 32)     │          6,144 │ block2b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 64, 64, 32)     │            128 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 64, 64, 32)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 64, 64, 32)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 64, 64, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_dwconv            │ (None, 64, 64, 192)    │          1,728 │ block2c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_bn                │ (None, 64, 64, 192)    │            768 │ block2c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_activation        │ (None, 64, 64, 192)    │              0 │ block2c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_squeeze        │ (None, 192)            │              0 │ block2c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_se_excite         │ (None, 64, 64, 192)    │              0 │ block2c_activation[0]… │
# │ (Multiply)                │                        │                │ block2c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 64, 64, 32)     │          6,144 │ block2c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 64, 64, 32)     │            128 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 64, 64, 32)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 64, 64, 32)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_activation │ (None, 64, 64, 192)    │              0 │ block2d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_dwconv            │ (None, 64, 64, 192)    │          1,728 │ block2d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_bn                │ (None, 64, 64, 192)    │            768 │ block2d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_activation        │ (None, 64, 64, 192)    │              0 │ block2d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_squeeze        │ (None, 192)            │              0 │ block2d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_reshape        │ (None, 1, 1, 192)      │              0 │ block2d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block2d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block2d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_se_excite         │ (None, 64, 64, 192)    │              0 │ block2d_activation[0]… │
# │ (Multiply)                │                        │                │ block2d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_conv      │ (None, 64, 64, 32)     │          6,144 │ block2d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_bn        │ (None, 64, 64, 32)     │            128 │ block2d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_drop (Dropout)    │ (None, 64, 64, 32)     │              0 │ block2d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_add (Add)         │ (None, 64, 64, 32)     │              0 │ block2d_drop[0][0],    │
# │                           │                        │                │ block2c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 64, 64, 192)    │          6,144 │ block2d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 64, 64, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 64, 64, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv_pad        │ (None, 67, 67, 192)    │              0 │ block3a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_dwconv            │ (None, 32, 32, 192)    │          4,800 │ block3a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_bn                │ (None, 32, 32, 192)    │            768 │ block3a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_activation        │ (None, 32, 32, 192)    │              0 │ block3a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_squeeze        │ (None, 192)            │              0 │ block3a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reshape        │ (None, 1, 1, 192)      │              0 │ block3a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_reduce         │ (None, 1, 1, 8)        │          1,544 │ block3a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_expand         │ (None, 1, 1, 192)      │          1,728 │ block3a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_se_excite         │ (None, 32, 32, 192)    │              0 │ block3a_activation[0]… │
# │ (Multiply)                │                        │                │ block3a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 32, 32, 56)     │         10,752 │ block3a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 32, 32, 56)     │            224 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 32, 32, 336)    │         18,816 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 32, 32, 336)    │          1,344 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 32, 32, 336)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_dwconv            │ (None, 32, 32, 336)    │          8,400 │ block3b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_bn                │ (None, 32, 32, 336)    │          1,344 │ block3b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_activation        │ (None, 32, 32, 336)    │              0 │ block3b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_squeeze        │ (None, 336)            │              0 │ block3b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reshape        │ (None, 1, 1, 336)      │              0 │ block3b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block3b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block3b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_se_excite         │ (None, 32, 32, 336)    │              0 │ block3b_activation[0]… │
# │ (Multiply)                │                        │                │ block3b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 32, 32, 56)     │         18,816 │ block3b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 32, 32, 56)     │            224 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 32, 32, 56)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 32, 32, 56)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 32, 32, 336)    │         18,816 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 32, 32, 336)    │          1,344 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 32, 32, 336)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_dwconv            │ (None, 32, 32, 336)    │          8,400 │ block3c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_bn                │ (None, 32, 32, 336)    │          1,344 │ block3c_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_activation        │ (None, 32, 32, 336)    │              0 │ block3c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_squeeze        │ (None, 336)            │              0 │ block3c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reshape        │ (None, 1, 1, 336)      │              0 │ block3c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block3c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block3c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_se_excite         │ (None, 32, 32, 336)    │              0 │ block3c_activation[0]… │
# │ (Multiply)                │                        │                │ block3c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 32, 32, 56)     │         18,816 │ block3c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 32, 32, 56)     │            224 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 32, 32, 56)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 32, 32, 56)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_conv       │ (None, 32, 32, 336)    │         18,816 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_bn         │ (None, 32, 32, 336)    │          1,344 │ block3d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_activation │ (None, 32, 32, 336)    │              0 │ block3d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_dwconv            │ (None, 32, 32, 336)    │          8,400 │ block3d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_bn                │ (None, 32, 32, 336)    │          1,344 │ block3d_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_activation        │ (None, 32, 32, 336)    │              0 │ block3d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_squeeze        │ (None, 336)            │              0 │ block3d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_reshape        │ (None, 1, 1, 336)      │              0 │ block3d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block3d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block3d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_se_excite         │ (None, 32, 32, 336)    │              0 │ block3d_activation[0]… │
# │ (Multiply)                │                        │                │ block3d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_conv      │ (None, 32, 32, 56)     │         18,816 │ block3d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_bn        │ (None, 32, 32, 56)     │            224 │ block3d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_drop (Dropout)    │ (None, 32, 32, 56)     │              0 │ block3d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_add (Add)         │ (None, 32, 32, 56)     │              0 │ block3d_drop[0][0],    │
# │                           │                        │                │ block3c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 32, 32, 336)    │         18,816 │ block3d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 32, 32, 336)    │          1,344 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 32, 32, 336)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv_pad        │ (None, 33, 33, 336)    │              0 │ block4a_expand_activa… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv            │ (None, 16, 16, 336)    │          3,024 │ block4a_dwconv_pad[0]… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 16, 16, 336)    │          1,344 │ block4a_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 16, 16, 336)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 336)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 336)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 14)       │          4,718 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 336)      │          5,040 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 16, 16, 336)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 16, 16, 112)    │         37,632 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 16, 16, 112)    │            448 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 16, 16, 672)    │         75,264 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 16, 16, 672)    │          2,688 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 16, 16, 672)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv            │ (None, 16, 16, 672)    │          6,048 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 16, 16, 672)    │          2,688 │ block4b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_expand_activation │ (None, 8, 8, 2688)     │              0 │ block7b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_dwconv            │ (None, 8, 8, 2688)     │         24,192 │ block7b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_bn                │ (None, 8, 8, 2688)     │         10,752 │ block7b_dwconv[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_activation        │ (None, 8, 8, 2688)     │              0 │ block7b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_squeeze        │ (None, 2688)           │              0 │ block7b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reshape        │ (None, 1, 1, 2688)     │              0 │ block7b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_reduce         │ (None, 1, 1, 112)      │        301,168 │ block7b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_expand         │ (None, 1, 1, 2688)     │        303,744 │ block7b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_se_excite         │ (None, 8, 8, 2688)     │              0 │ block7b_activation[0]… │
# │ (Multiply)                │                        │                │ block7b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_conv      │ (None, 8, 8, 448)      │      1,204,224 │ block7b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_project_bn        │ (None, 8, 8, 448)      │          1,792 │ block7b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_drop (Dropout)    │ (None, 8, 8, 448)      │              0 │ block7b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block7b_add (Add)         │ (None, 8, 8, 448)      │              0 │ block7b_drop[0][0],    │
# │                           │                        │                │ block7a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 8, 8, 1792)     │        802,816 │ block7b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 8, 8, 1792)     │          7,168 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 8, 8, 1792)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 16, 16, 1792)   │              0 │ top_activation[0][0]   │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 16, 16, 272)    │        487,696 │ up_sampling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 1232)   │              0 │ conv2d[0][0],          │
# │                           │                        │                │ block6a_expand_activa… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 16, 16, 272)    │      3,016,208 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 16, 16, 272)    │              0 │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 16, 16, 272)    │        666,128 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 272)            │              0 │ conv2d_2[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 17)             │          4,641 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 272)            │          4,896 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 272)      │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 16, 16, 272)    │              0 │ conv2d_2[0][0],        │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 32, 32, 272)    │              0 │ multiply[0][0]         │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 32, 32, 112)    │         30,576 │ up_sampling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 32, 32, 448)    │              0 │ conv2d_3[0][0],        │
# │ (Concatenate)             │                        │                │ block4a_expand_activa… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 112)    │        451,696 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 32, 32, 112)    │              0 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 32, 32, 112)    │        113,008 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 112)            │              0 │ conv2d_5[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 7)              │            791 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 112)            │            896 │ dense_2[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 112)      │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 32, 32, 112)    │              0 │ conv2d_5[0][0],        │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 64, 64, 112)    │              0 │ multiply_1[0][0]       │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 64, 64, 56)     │          6,328 │ up_sampling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 64, 64, 248)    │              0 │ conv2d_6[0][0],        │
# │ (Concatenate)             │                        │                │ block3a_expand_activa… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 64, 64, 56)     │        125,048 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 64, 64, 56)     │              0 │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 64, 64, 56)     │         28,280 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 56)             │              0 │ conv2d_8[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 3)              │            171 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 56)             │            224 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 56)       │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 64, 64, 56)     │              0 │ conv2d_8[0][0],        │
# │                           │                        │                │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 56)   │              0 │ multiply_2[0][0]       │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 128, 128, 32)   │          1,824 │ up_sampling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 128, 128, 176)  │              0 │ conv2d_9[0][0],        │
# │ (Concatenate)             │                        │                │ block2a_expand_activa… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 128, 128, 32)   │         50,720 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 128, 128, 32)   │              0 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 128, 128, 32)   │          9,248 │ dropout_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 32)             │              0 │ conv2d_11[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 2)              │             66 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 32)             │             96 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 32)       │              0 │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 128, 128, 32)   │              0 │ conv2d_11[0][0],       │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_4           │ (None, 256, 256, 32)   │              0 │ multiply_3[0][0]       │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 256, 256, 32)   │          9,248 │ up_sampling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 256, 256, 32)   │              0 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 256, 256, 32)   │          9,248 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 256, 256, 1)    │             33 │ conv2d_13[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 22,690,893 (86.56 MB)
#  Trainable params: 22,565,686 (86.08 MB)
#  Non-trainable params: 125,207 (489.09 KB)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, UpSampling2D, concatenate, GlobalAveragePooling2D, Dense, Reshape, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2


def tversky_loss(y_true, y_pred, alpha=0.6, beta=0.4, epsilon=1e-6):
    # Flatten the input tensors
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])

    # True Positives (TP), False Positives (FP), False Negatives (FN)
    TP = tf.reduce_sum(y_true * y_pred)
    FP = tf.reduce_sum((1 - y_true) * y_pred)
    FN = tf.reduce_sum(y_true * (1 - y_pred))

    # Calculate the Tversky Index
    tversky_index = (TP + epsilon) / (TP + alpha * FP + beta * FN + epsilon)

    # Tversky Loss is the complement of the Tversky Index
    return 1 - tversky_index




# Loss and Metric Functions
def dice_loss(y_true, y_pred):
    smooth = 1e-6
    intersection = tf.reduce_sum(y_true * y_pred)
    return 1 - (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def iou_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = intersection / (union + 1e-6)
    return 1 - iou

def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    y_true = tf.cast(y_true, tf.float32)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    loss = alpha * tf.pow(1 - y_pred, gamma) * bce
    return loss

# %%
def combo_loss(y_true, y_pred, dice_weight=0.3, bce_weight=0.2,iou_weight=0.1,tversky_weight=0.4, pos_weight=6.0, neg_weight=1.0):
    y_true = tf.cast(y_true, tf.float32)

    # Dice Loss
    dice = dice_loss(y_true, y_pred)

    # Binary Cross-Entropy (Weighted)
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    weighted_bce = pos_weight * y_true * bce + neg_weight * (1 - y_true) * bce

    # IoU Loss
    iou = iou_loss(y_true, y_pred)

    # Tversky Loss (For Imbalance)
    tversky = tversky_loss(y_true, y_pred)

    # Compute final loss with weights
    return (dice_weight * dice +
            bce_weight * tf.reduce_mean(weighted_bce) + iou_weight * iou + tversky_weight * tversky
            )

# %%
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.optimizers import Adam


# Define Adam optimizer with an initial learning rate
initial_lr = 1e-4
optimizer = Adam(learning_rate=initial_lr)


def lr_schedule(epoch, lr):
    if epoch < 5:  # Warmup phase
        return lr * 1.5  # Increase LR to stabilize training
    elif epoch < 30:
        return lr * 0.98  # Gradual decay
    else:
        return lr * 0.95  # Final stabilization

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
import tensorflow.keras.backend as K

smooth = 1


def iou(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)  # Cast y_true to float32
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    return intersection / (union + 1e-6)
# Create the metric objects outside the functions
prec = tf.keras.metrics.Precision()
rec = tf.keras.metrics.Recall()

def f1_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 2 * ((p * r) / (p + r + 1e-6))

def f2_score(y_true, y_pred):
    # Update states using the global metric objects
    prec.update_state(y_true, y_pred)
    rec.update_state(y_true, y_pred)

    p = prec.result()
    r = rec.result()

    # Reseting states for the next call
    prec.reset_state()
    rec.reset_state()

    return 5 * ((p * r) / ((4 * p) + r + 1e-6))

def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(tf.cast(y_true, tf.float32))  # Cast y_true to float32
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# In your model.compile call:
model.compile(optimizer=optimizer, loss=combo_loss, metrics=[iou,dice_coef, f1_score, f2_score, tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',    # Monitor validation loss
    patience=10,            # Stop if no improvement for 5 epochs
    restore_best_weights=True  # Restore best model weights
)

# Compile the model (assuming bce_dice_loss, iou, f1_score, etc., are defined)
# model.compile(optimizer=Adam(learning_rate=1e-4), loss=bce_dice_loss, metrics=[iou, f1_score, f2_score, Precision(), Recall()])

# Train the model with Early Stopping
history = model.fit(
    final_x_train, final_y_train,
    validation_data=(x_val, y_val),
    epochs=50,
    batch_size=8,
    callbacks=[early_stopping,lr_scheduler]  # Add the Early Stopping callback
)
# Out:
# Epoch 1/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 291s 550ms/step - dice_coef: 0.4317 - f1_score: 0.4063 - f2_score: 0.4148 - iou: 0.3146 - loss: 0.7244 - precision_1: 0.4124 - recall_1: 0.4372 - val_dice_coef: 0.8287 - val_f1_score: 0.8350 - val_f2_score: 0.7925 - val_iou: 0.7108 - val_loss: 0.2975 - val_precision_1: 0.9319 - val_recall_1: 0.7660 - learning_rate: 1.5000e-04
# Epoch 2/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.8719 - f1_score: 0.8797 - f2_score: 0.8705 - iou: 0.7749 - loss: 0.2577 - precision_1: 0.9052 - recall_1: 0.8620 - val_dice_coef: 0.8952 - val_f1_score: 0.9031 - val_f2_score: 0.9113 - val_iou: 0.8110 - val_loss: 0.2187 - val_precision_1: 0.8973 - val_recall_1: 0.9129 - learning_rate: 2.2500e-04
# Epoch 3/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9020 - f1_score: 0.9078 - f2_score: 0.9012 - iou: 0.8239 - loss: 0.2092 - precision_1: 0.9277 - recall_1: 0.8937 - val_dice_coef: 0.9063 - val_f1_score: 0.9112 - val_f2_score: 0.9157 - val_iou: 0.8289 - val_loss: 0.1902 - val_precision_1: 0.9096 - val_recall_1: 0.9150 - learning_rate: 3.3750e-04
# Epoch 4/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.9129 - f1_score: 0.9182 - f2_score: 0.9103 - iou: 0.8420 - loss: 0.1825 - precision_1: 0.9382 - recall_1: 0.9021 - val_dice_coef: 0.8957 - val_f1_score: 0.9047 - val_f2_score: 0.9261 - val_iou: 0.8129 - val_loss: 0.1887 - val_precision_1: 0.8848 - val_recall_1: 0.9379 - learning_rate: 5.0625e-04
# Epoch 5/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9120 - f1_score: 0.9178 - f2_score: 0.9134 - iou: 0.8401 - loss: 0.1699 - precision_1: 0.9317 - recall_1: 0.9088 - val_dice_coef: 0.8318 - val_f1_score: 0.8378 - val_f2_score: 0.7851 - val_iou: 0.7176 - val_loss: 0.2468 - val_precision_1: 0.9534 - val_recall_1: 0.7531 - learning_rate: 7.5938e-04
# Epoch 6/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.8961 - f1_score: 0.9027 - f2_score: 0.8951 - iou: 0.8148 - loss: 0.1789 - precision_1: 0.9231 - recall_1: 0.8868 - val_dice_coef: 0.9086 - val_f1_score: 0.9121 - val_f2_score: 0.9032 - val_iou: 0.8353 - val_loss: 0.1543 - val_precision_1: 0.9311 - val_recall_1: 0.8951 - learning_rate: 7.4419e-04
# Epoch 7/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - dice_coef: 0.9150 - f1_score: 0.9195 - f2_score: 0.9134 - iou: 0.8455 - loss: 0.1421 - precision_1: 0.9359 - recall_1: 0.9080 - val_dice_coef: 0.8767 - val_f1_score: 0.8784 - val_f2_score: 0.8743 - val_iou: 0.7846 - val_loss: 0.1787 - val_precision_1: 0.8969 - val_recall_1: 0.8777 - learning_rate: 7.2930e-04
# Epoch 8/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - dice_coef: 0.9305 - f1_score: 0.9343 - f2_score: 0.9291 - iou: 0.8713 - loss: 0.1174 - precision_1: 0.9470 - recall_1: 0.9256 - val_dice_coef: 0.8905 - val_f1_score: 0.8948 - val_f2_score: 0.9216 - val_iou: 0.8083 - val_loss: 0.1574 - val_precision_1: 0.8469 - val_recall_1: 0.9390 - learning_rate: 7.1472e-04
# Epoch 9/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - dice_coef: 0.9274 - f1_score: 0.9317 - f2_score: 0.9267 - iou: 0.8662 - loss: 0.1155 - precision_1: 0.9436 - recall_1: 0.9212 - val_dice_coef: 0.9273 - val_f1_score: 0.9305 - val_f2_score: 0.9267 - val_iou: 0.8650 - val_loss: 0.1104 - val_precision_1: 0.9406 - val_recall_1: 0.9254 - learning_rate: 7.0042e-04
# Epoch 10/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.9437 - f1_score: 0.9470 - f2_score: 0.9448 - iou: 0.8943 - loss: 0.0922 - precision_1: 0.9545 - recall_1: 0.9419 - val_dice_coef: 0.9221 - val_f1_score: 0.9271 - val_f2_score: 0.9217 - val_iou: 0.8562 - val_loss: 0.1134 - val_precision_1: 0.9362 - val_recall_1: 0.9175 - learning_rate: 6.8641e-04
# Epoch 11/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 161ms/step - dice_coef: 0.9446 - f1_score: 0.9479 - f2_score: 0.9429 - iou: 0.8957 - loss: 0.0898 - precision_1: 0.9595 - recall_1: 0.9379 - val_dice_coef: 0.9285 - val_f1_score: 0.9309 - val_f2_score: 0.9205 - val_iou: 0.8669 - val_loss: 0.1011 - val_precision_1: 0.9524 - val_recall_1: 0.9113 - learning_rate: 6.7269e-04
# Epoch 12/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.9489 - f1_score: 0.9518 - f2_score: 0.9479 - iou: 0.9038 - loss: 0.0791 - precision_1: 0.9619 - recall_1: 0.9449 - val_dice_coef: 0.9317 - val_f1_score: 0.9342 - val_f2_score: 0.9295 - val_iou: 0.8726 - val_loss: 0.0977 - val_precision_1: 0.9465 - val_recall_1: 0.9241 - learning_rate: 6.5923e-04
# Epoch 13/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.9503 - f1_score: 0.9529 - f2_score: 0.9493 - iou: 0.9056 - loss: 0.0766 - precision_1: 0.9617 - recall_1: 0.9484 - val_dice_coef: 0.9381 - val_f1_score: 0.9398 - val_f2_score: 0.9292 - val_iou: 0.8836 - val_loss: 0.0856 - val_precision_1: 0.9618 - val_recall_1: 0.9204 - learning_rate: 6.4605e-04
# Epoch 14/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9514 - f1_score: 0.9540 - f2_score: 0.9505 - iou: 0.9078 - loss: 0.0723 - precision_1: 0.9626 - recall_1: 0.9483 - val_dice_coef: 0.9263 - val_f1_score: 0.9291 - val_f2_score: 0.9353 - val_iou: 0.8641 - val_loss: 0.0967 - val_precision_1: 0.9269 - val_recall_1: 0.9385 - learning_rate: 6.3313e-04
# Epoch 15/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9511 - f1_score: 0.9537 - f2_score: 0.9485 - iou: 0.9072 - loss: 0.0710 - precision_1: 0.9657 - recall_1: 0.9455 - val_dice_coef: 0.9252 - val_f1_score: 0.9270 - val_f2_score: 0.9124 - val_iou: 0.8613 - val_loss: 0.0969 - val_precision_1: 0.9572 - val_recall_1: 0.8965 - learning_rate: 6.2046e-04
# Epoch 16/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 160ms/step - dice_coef: 0.9543 - f1_score: 0.9569 - f2_score: 0.9525 - iou: 0.9129 - loss: 0.0661 - precision_1: 0.9668 - recall_1: 0.9504 - val_dice_coef: 0.9369 - val_f1_score: 0.9389 - val_f2_score: 0.9372 - val_iou: 0.8816 - val_loss: 0.0836 - val_precision_1: 0.9465 - val_recall_1: 0.9348 - learning_rate: 6.0806e-04
# Epoch 17/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9479 - f1_score: 0.9508 - f2_score: 0.9466 - iou: 0.9019 - loss: 0.0724 - precision_1: 0.9607 - recall_1: 0.9439 - val_dice_coef: 0.9231 - val_f1_score: 0.9266 - val_f2_score: 0.9234 - val_iou: 0.8580 - val_loss: 0.1018 - val_precision_1: 0.9364 - val_recall_1: 0.9181 - learning_rate: 5.9589e-04
# Epoch 18/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 159ms/step - dice_coef: 0.9502 - f1_score: 0.9532 - f2_score: 0.9489 - iou: 0.9057 - loss: 0.0716 - precision_1: 0.9626 - recall_1: 0.9462 - val_dice_coef: 0.9316 - val_f1_score: 0.9340 - val_f2_score: 0.9266 - val_iou: 0.8727 - val_loss: 0.0876 - val_precision_1: 0.9518 - val_recall_1: 0.9180 - learning_rate: 5.8398e-04
# Epoch 19/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9600 - f1_score: 0.9621 - f2_score: 0.9588 - iou: 0.9234 - loss: 0.0562 - precision_1: 0.9696 - recall_1: 0.9576 - val_dice_coef: 0.9356 - val_f1_score: 0.9373 - val_f2_score: 0.9413 - val_iou: 0.8796 - val_loss: 0.0837 - val_precision_1: 0.9359 - val_recall_1: 0.9413 - learning_rate: 5.7230e-04
# Epoch 20/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9614 - f1_score: 0.9634 - f2_score: 0.9601 - iou: 0.9258 - loss: 0.0528 - precision_1: 0.9711 - recall_1: 0.9592 - val_dice_coef: 0.9368 - val_f1_score: 0.9391 - val_f2_score: 0.9457 - val_iou: 0.8818 - val_loss: 0.0807 - val_precision_1: 0.9328 - val_recall_1: 0.9482 - learning_rate: 5.6085e-04
# Epoch 21/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 159ms/step - dice_coef: 0.9626 - f1_score: 0.9646 - f2_score: 0.9614 - iou: 0.9280 - loss: 0.0505 - precision_1: 0.9713 - recall_1: 0.9609 - val_dice_coef: 0.9352 - val_f1_score: 0.9374 - val_f2_score: 0.9315 - val_iou: 0.8788 - val_loss: 0.0820 - val_precision_1: 0.9517 - val_recall_1: 0.9245 - learning_rate: 5.4963e-04
# Epoch 22/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9630 - f1_score: 0.9650 - f2_score: 0.9621 - iou: 0.9289 - loss: 0.0503 - precision_1: 0.9721 - recall_1: 0.9614 - val_dice_coef: 0.9282 - val_f1_score: 0.9303 - val_f2_score: 0.9384 - val_iou: 0.8678 - val_loss: 0.0916 - val_precision_1: 0.9220 - val_recall_1: 0.9447 - learning_rate: 5.3864e-04
# Epoch 23/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9525 - f1_score: 0.9551 - f2_score: 0.9519 - iou: 0.9098 - loss: 0.0641 - precision_1: 0.9622 - recall_1: 0.9502 - val_dice_coef: 0.9408 - val_f1_score: 0.9429 - val_f2_score: 0.9326 - val_iou: 0.8886 - val_loss: 0.0750 - val_precision_1: 0.9628 - val_recall_1: 0.9233 - learning_rate: 5.2787e-04
# Epoch 24/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9642 - f1_score: 0.9661 - f2_score: 0.9624 - iou: 0.9310 - loss: 0.0494 - precision_1: 0.9737 - recall_1: 0.9609 - val_dice_coef: 0.9425 - val_f1_score: 0.9447 - val_f2_score: 0.9308 - val_iou: 0.8914 - val_loss: 0.0695 - val_precision_1: 0.9710 - val_recall_1: 0.9218 - learning_rate: 5.1731e-04
# Epoch 25/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9517 - f1_score: 0.9547 - f2_score: 0.9504 - iou: 0.9088 - loss: 0.0642 - precision_1: 0.9656 - recall_1: 0.9454 - val_dice_coef: 0.9426 - val_f1_score: 0.9446 - val_f2_score: 0.9428 - val_iou: 0.8920 - val_loss: 0.0729 - val_precision_1: 0.9488 - val_recall_1: 0.9422 - learning_rate: 5.0696e-04
# Epoch 26/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9607 - f1_score: 0.9628 - f2_score: 0.9589 - iou: 0.9248 - loss: 0.0520 - precision_1: 0.9711 - recall_1: 0.9574 - val_dice_coef: 0.9141 - val_f1_score: 0.9175 - val_f2_score: 0.9192 - val_iou: 0.8436 - val_loss: 0.1074 - val_precision_1: 0.9201 - val_recall_1: 0.9195 - learning_rate: 4.9683e-04
# Epoch 27/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 159ms/step - dice_coef: 0.9510 - f1_score: 0.9537 - f2_score: 0.9489 - iou: 0.9073 - loss: 0.0660 - precision_1: 0.9652 - recall_1: 0.9456 - val_dice_coef: 0.9266 - val_f1_score: 0.9284 - val_f2_score: 0.9259 - val_iou: 0.8648 - val_loss: 0.0933 - val_precision_1: 0.9393 - val_recall_1: 0.9187 - learning_rate: 4.8689e-04
# Epoch 28/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9597 - f1_score: 0.9618 - f2_score: 0.9584 - iou: 0.9228 - loss: 0.0547 - precision_1: 0.9691 - recall_1: 0.9565 - val_dice_coef: 0.9366 - val_f1_score: 0.9382 - val_f2_score: 0.9372 - val_iou: 0.8812 - val_loss: 0.0792 - val_precision_1: 0.9431 - val_recall_1: 0.9366 - learning_rate: 4.7715e-04
# Epoch 29/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9633 - f1_score: 0.9651 - f2_score: 0.9620 - iou: 0.9292 - loss: 0.0484 - precision_1: 0.9717 - recall_1: 0.9604 - val_dice_coef: 0.9450 - val_f1_score: 0.9470 - val_f2_score: 0.9482 - val_iou: 0.8962 - val_loss: 0.0680 - val_precision_1: 0.9483 - val_recall_1: 0.9482 - learning_rate: 4.6761e-04
# Epoch 30/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9629 - f1_score: 0.9650 - f2_score: 0.9616 - iou: 0.9287 - loss: 0.0485 - precision_1: 0.9722 - recall_1: 0.9600 - val_dice_coef: 0.9384 - val_f1_score: 0.9402 - val_f2_score: 0.9378 - val_iou: 0.8851 - val_loss: 0.0768 - val_precision_1: 0.9485 - val_recall_1: 0.9371 - learning_rate: 4.5826e-04
# Epoch 31/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9652 - f1_score: 0.9670 - f2_score: 0.9637 - iou: 0.9328 - loss: 0.0459 - precision_1: 0.9739 - recall_1: 0.9625 - val_dice_coef: 0.9398 - val_f1_score: 0.9412 - val_f2_score: 0.9308 - val_iou: 0.8869 - val_loss: 0.0727 - val_precision_1: 0.9615 - val_recall_1: 0.9234 - learning_rate: 4.3534e-04
# Epoch 32/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9676 - f1_score: 0.9692 - f2_score: 0.9667 - iou: 0.9373 - loss: 0.0416 - precision_1: 0.9752 - recall_1: 0.9662 - val_dice_coef: 0.9481 - val_f1_score: 0.9500 - val_f2_score: 0.9502 - val_iou: 0.9016 - val_loss: 0.0633 - val_precision_1: 0.9521 - val_recall_1: 0.9499 - learning_rate: 4.1358e-04
# Epoch 33/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9681 - f1_score: 0.9699 - f2_score: 0.9674 - iou: 0.9383 - loss: 0.0407 - precision_1: 0.9754 - recall_1: 0.9667 - val_dice_coef: 0.9073 - val_f1_score: 0.9084 - val_f2_score: 0.9194 - val_iou: 0.8359 - val_loss: 0.1225 - val_precision_1: 0.8914 - val_recall_1: 0.9268 - learning_rate: 3.9290e-04
# Epoch 34/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9674 - f1_score: 0.9692 - f2_score: 0.9662 - iou: 0.9369 - loss: 0.0427 - precision_1: 0.9754 - recall_1: 0.9655 - val_dice_coef: 0.9440 - val_f1_score: 0.9451 - val_f2_score: 0.9458 - val_iou: 0.8942 - val_loss: 0.0701 - val_precision_1: 0.9480 - val_recall_1: 0.9444 - learning_rate: 3.7325e-04
# Epoch 35/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9688 - f1_score: 0.9704 - f2_score: 0.9675 - iou: 0.9396 - loss: 0.0396 - precision_1: 0.9764 - recall_1: 0.9669 - val_dice_coef: 0.9479 - val_f1_score: 0.9494 - val_f2_score: 0.9472 - val_iou: 0.9014 - val_loss: 0.0636 - val_precision_1: 0.9568 - val_recall_1: 0.9451 - learning_rate: 3.5459e-04
# Epoch 36/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9701 - f1_score: 0.9717 - f2_score: 0.9694 - iou: 0.9421 - loss: 0.0374 - precision_1: 0.9768 - recall_1: 0.9694 - val_dice_coef: 0.9407 - val_f1_score: 0.9425 - val_f2_score: 0.9331 - val_iou: 0.8886 - val_loss: 0.0703 - val_precision_1: 0.9617 - val_recall_1: 0.9273 - learning_rate: 3.3686e-04
# Epoch 37/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9699 - f1_score: 0.9716 - f2_score: 0.9688 - iou: 0.9417 - loss: 0.0378 - precision_1: 0.9777 - recall_1: 0.9679 - val_dice_coef: 0.9476 - val_f1_score: 0.9486 - val_f2_score: 0.9494 - val_iou: 0.9007 - val_loss: 0.0646 - val_precision_1: 0.9514 - val_recall_1: 0.9492 - learning_rate: 3.2002e-04
# Epoch 38/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 159ms/step - dice_coef: 0.9707 - f1_score: 0.9722 - f2_score: 0.9699 - iou: 0.9431 - loss: 0.0369 - precision_1: 0.9774 - recall_1: 0.9696 - val_dice_coef: 0.9484 - val_f1_score: 0.9494 - val_f2_score: 0.9449 - val_iou: 0.9022 - val_loss: 0.0629 - val_precision_1: 0.9603 - val_recall_1: 0.9414 - learning_rate: 3.0402e-04
# Epoch 39/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9729 - f1_score: 0.9743 - f2_score: 0.9720 - iou: 0.9472 - loss: 0.0341 - precision_1: 0.9795 - recall_1: 0.9714 - val_dice_coef: 0.9438 - val_f1_score: 0.9449 - val_f2_score: 0.9408 - val_iou: 0.8938 - val_loss: 0.0672 - val_precision_1: 0.9557 - val_recall_1: 0.9364 - learning_rate: 2.8882e-04
# Epoch 40/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9730 - f1_score: 0.9745 - f2_score: 0.9723 - iou: 0.9476 - loss: 0.0338 - precision_1: 0.9790 - recall_1: 0.9721 - val_dice_coef: 0.9458 - val_f1_score: 0.9471 - val_f2_score: 0.9481 - val_iou: 0.8975 - val_loss: 0.0657 - val_precision_1: 0.9492 - val_recall_1: 0.9477 - learning_rate: 2.7437e-04
# Epoch 41/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9737 - f1_score: 0.9751 - f2_score: 0.9730 - iou: 0.9487 - loss: 0.0329 - precision_1: 0.9794 - recall_1: 0.9725 - val_dice_coef: 0.9496 - val_f1_score: 0.9510 - val_f2_score: 0.9539 - val_iou: 0.9043 - val_loss: 0.0618 - val_precision_1: 0.9501 - val_recall_1: 0.9551 - learning_rate: 2.6066e-04
# Epoch 42/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 157ms/step - dice_coef: 0.9739 - f1_score: 0.9753 - f2_score: 0.9734 - iou: 0.9492 - loss: 0.0325 - precision_1: 0.9794 - recall_1: 0.9732 - val_dice_coef: 0.9469 - val_f1_score: 0.9477 - val_f2_score: 0.9408 - val_iou: 0.8994 - val_loss: 0.0643 - val_precision_1: 0.9625 - val_recall_1: 0.9353 - learning_rate: 2.4762e-04
# Epoch 43/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9743 - f1_score: 0.9757 - f2_score: 0.9736 - iou: 0.9499 - loss: 0.0320 - precision_1: 0.9800 - recall_1: 0.9733 - val_dice_coef: 0.9497 - val_f1_score: 0.9507 - val_f2_score: 0.9521 - val_iou: 0.9045 - val_loss: 0.0621 - val_precision_1: 0.9522 - val_recall_1: 0.9526 - learning_rate: 2.3524e-04
# Epoch 44/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9749 - f1_score: 0.9763 - f2_score: 0.9746 - iou: 0.9511 - loss: 0.0313 - precision_1: 0.9802 - recall_1: 0.9745 - val_dice_coef: 0.9490 - val_f1_score: 0.9500 - val_f2_score: 0.9495 - val_iou: 0.9032 - val_loss: 0.0628 - val_precision_1: 0.9543 - val_recall_1: 0.9484 - learning_rate: 2.2348e-04
# Epoch 45/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9750 - f1_score: 0.9764 - f2_score: 0.9746 - iou: 0.9513 - loss: 0.0310 - precision_1: 0.9808 - recall_1: 0.9742 - val_dice_coef: 0.9472 - val_f1_score: 0.9481 - val_f2_score: 0.9422 - val_iou: 0.9000 - val_loss: 0.0644 - val_precision_1: 0.9614 - val_recall_1: 0.9362 - learning_rate: 2.1231e-04
# Epoch 46/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9753 - f1_score: 0.9766 - f2_score: 0.9747 - iou: 0.9518 - loss: 0.0306 - precision_1: 0.9807 - recall_1: 0.9743 - val_dice_coef: 0.9377 - val_f1_score: 0.9392 - val_f2_score: 0.9594 - val_iou: 0.8830 - val_loss: 0.0785 - val_precision_1: 0.9114 - val_recall_1: 0.9733 - learning_rate: 2.0169e-04
# Epoch 47/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 40s 159ms/step - dice_coef: 0.9682 - f1_score: 0.9704 - f2_score: 0.9692 - iou: 0.9386 - loss: 0.0398 - precision_1: 0.9740 - recall_1: 0.9690 - val_dice_coef: 0.9519 - val_f1_score: 0.9529 - val_f2_score: 0.9501 - val_iou: 0.9085 - val_loss: 0.0593 - val_precision_1: 0.9606 - val_recall_1: 0.9492 - learning_rate: 1.9161e-04
# Epoch 48/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9760 - f1_score: 0.9774 - f2_score: 0.9755 - iou: 0.9533 - loss: 0.0302 - precision_1: 0.9817 - recall_1: 0.9752 - val_dice_coef: 0.9520 - val_f1_score: 0.9530 - val_f2_score: 0.9503 - val_iou: 0.9086 - val_loss: 0.0589 - val_precision_1: 0.9604 - val_recall_1: 0.9494 - learning_rate: 1.8203e-04
# Epoch 49/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 157ms/step - dice_coef: 0.9772 - f1_score: 0.9785 - f2_score: 0.9768 - iou: 0.9555 - loss: 0.0287 - precision_1: 0.9821 - recall_1: 0.9762 - val_dice_coef: 0.9478 - val_f1_score: 0.9486 - val_f2_score: 0.9447 - val_iou: 0.9011 - val_loss: 0.0636 - val_precision_1: 0.9582 - val_recall_1: 0.9422 - learning_rate: 1.7292e-04
# Epoch 50/50
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 39s 158ms/step - dice_coef: 0.9775 - f1_score: 0.9788 - f2_score: 0.9771 - iou: 0.9561 - loss: 0.0281 - precision_1: 0.9823 - recall_1: 0.9766 - val_dice_coef: 0.9416 - val_f1_score: 0.9427 - val_f2_score: 0.9322 - val_iou: 0.8900 - val_loss: 0.0697 - val_precision_1: 0.9637 - val_recall_1: 0.9226 - learning_rate: 1.6428e-04

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the object returned by model.fit()
def plot_loss(history):
    plt.figure(figsize=(8, 6))

    # Plot training & validation loss
    plt.plot(history.history['loss'], label='Train Loss', color='blue')
    plt.plot(history.history['val_loss'], label='Val Loss', color='red')

    # Labels and title
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid()

    # Show the plot
    plt.show()

# Call the function after training
plot_loss(history)

# %%
y_pred = model.predict(x_test)  # Predict masks for test images
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 31s 15s/step

# %%
y_pred_thresholded = (y_pred > 0.5).astype(np.uint8)  # Convert probability map to binary mask

# %%
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
print("y_pred shape:", y_pred.shape)
print("y_pred_thresholded shape:", y_pred_thresholded.shape)
# Out:
# x_test shape: (62, 256, 256, 3)
# y_test shape: (62, 256, 256, 1)
# y_pred shape: (62, 256, 256, 1)
# y_pred_thresholded shape: (62, 256, 256, 1)

# %%
import matplotlib.pyplot as plt
import random

# Select a random test image
index = random.randint(0, len(x_test) - 1)

plt.figure(figsize=(15, 5))

# Original test image
plt.subplot(1, 3, 1)
plt.imshow(x_test[index])
plt.title("Test Image")

# Ground truth mask
plt.subplot(1, 3, 2)
plt.imshow(y_test[index, :, :, 0], cmap='gray')
plt.title("Ground Truth Mask")

# Predicted mask (thresholded)
plt.subplot(1, 3, 3)
plt.imshow(y_pred_thresholded[index, :, :, 0], cmap='gray')
plt.title("Predicted Mask")

plt.show()

# %%
import tensorflow as tf
import numpy as np

# Lists to store scores
dice_scores = []
iou_scores = []

# Initialize the Keras Precision and Recall metrics
precision_metric = tf.keras.metrics.Precision()
recall_metric = tf.keras.metrics.Recall()

# Loop through each test sample
for i in range(len(y_test)):
    # Convert to float32 before calculation
    y_true = y_test[i].astype(np.float32)
    y_pred = y_pred_thresholded[i].astype(np.float32)

    # Calculate Dice and IoU
    dice = dice_coef(y_true, y_pred)  # Assuming `dice_coef` is defined
    iou_score = iou(y_true, y_pred)   # Assuming `iou` is defined

    # Update Precision and Recall metrics
    precision_metric.update_state(y_true, y_pred)
    recall_metric.update_state(y_true, y_pred)

    # Append scores
    dice_scores.append(dice)
    iou_scores.append(iou_score)

# Compute overall metrics
dice_score = np.mean(dice_scores)
iou_score = np.mean(iou_scores)
precision = precision_metric.result().numpy()
recall = recall_metric.result().numpy()

# Compute F1 and F2 scores
if precision + recall > 0:
    f1_score = 2 * (precision * recall) / (precision + recall)
    f2_score = 5 * (precision * recall) / (4 * precision + recall)
else:
    f1_score, f2_score = 0.0, 0.0  # Avoid division by zero

# Print results
print(f"Dice Score: {dice_score:.4f}")
print(f"IoU Score: {iou_score:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"F2 Score: {f2_score:.4f}")
# Out:
# Dice Score: 0.9489
# IoU Score: 0.9045
# Precision: 0.9488
# Recall: 0.9602
# F1 Score: 0.9545
# F2 Score: 0.9579
